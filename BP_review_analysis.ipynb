# %% [markdown]
# ### **Batch Processing of Reviews using Spacy and Parallel Processing**

# %% [markdown]
# In this notebook, we the following is conducted:
# - Batch processing of reviews using spaCy
# - Batch + Parallel processing of reviews using spaCy (using ThreadpoolExecutor)

# %%
import pandas as pd
import re
import spacy 
import time
import tracemalloc

# %%
df_reviews  = pd.read_csv('Projects/df_review_analysis.csv')
df_reviews.head(5)
# Out:
#                    drugName                     condition  \
# 0                 Valsartan  Left Ventricular Dysfunction
# 1                Guanfacine                          ADHD
# 2                    Lybrel                 Birth Control
# 3                Ortho Evra                 Birth Control
# 4  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating        date  \
# 0  "It has no side effect, I take it in combinati...       9  2012-05-20
# 1  "My son is halfway through his fourth week of ...       8  2010-04-27
# 2  "I used to take another oral contraceptive, wh...       5  2009-12-14
# 3  "This is my first time using any form of birth...       8  2015-11-03
# 4  "Suboxone has completely turned my life around...       9  2016-11-27
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37

# %%
# Load spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
review_list = df_reviews["review"].dropna().tolist()

# %% [markdown]
# #### **Batch Processing of Reviews using Spacy**

# %%
def chunk_generator(iterable, chunk_size):
    for i in range(0, len(iterable), chunk_size):
        yield iterable[i:i+chunk_size]  # using yield generator method to generate data chunk on the fly and not load on in memory

def data_stripper(text):
    # Convert the input text to lowercase
    text = text.lower()
    # Remove standalone numbers
    text = re.sub(r'\b\d+\b', '', text)
    # Remove special characters, keeping only alphanumeric characters and spaces
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Remove any extra whitespace (including newlines /n)
    text = re.sub(r'\s+', ' ', text).strip()
    return text  # lets think on it whether to use yield or return benefit

# def preprocess_text_spacy_pipe(chunk=None, batch_size=None, stop=False, lemmer=True, return_tokens=False):
#     processed_texts = []
#     processed_tokens = []
#     for doc in nlp.pipe(chunk, batch_size=batch_size):
#         tokens = []
#         for token in doc:
#             if stop and token.is_stop:
#                 continue
#             if lemmer:
#                 tokens.append(token.lemma_)
#             else:
#                 tokens.append(token.text)
#         prepro_text = ' '.join(tokens)
#         # processed_tokens.append(tokens)
#         processed_texts.append(prepro_text)
#     return tokens,processed_texts

def preprocess_text_spacy_pipe(chunk=None, batch_size=None, stop=False, lemmer=True, return_tokens=False):
    processed_texts = []
    all_tokens = []
    for doc in nlp.pipe(chunk, batch_size=batch_size):
        tokens = []
        for token in doc:
            if stop and token.is_stop:
                continue
            if lemmer:
                tokens.append(token.lemma_)
            else:
                tokens.append(token.text)
        prepro_text = ' '.join(tokens)
        processed_texts.append(prepro_text)
        if return_tokens:
            all_tokens.append(tokens)
    if return_tokens:
        return all_tokens, processed_texts
    else:
        return processed_texts

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Define the chunk size
chunk_size = 100

# Create chunks using the generator
chunks = chunk_generator(review_list, chunk_size)

# List to store tokenized reviews
review_token_list = []
review_text_list = []

# Start measuring time and memory
start_time = time.time()
tracemalloc.start()

# Process each chunk
for chunk in chunks:
    # Instead of storing stripped_chunk, process each review on-the-fly
    stripped_chunk = (data_stripper(review) for review in chunk)
    # Process the stripped chunk with spaCy
    processed_tokens, prepro_texts = preprocess_text_spacy_pipe(stripped_chunk, batch_size=25, lemmer=True, return_tokens= True)
    # Append the processed texts to the review_token_list
    review_token_list.append(processed_tokens)
    review_text_list.append(prepro_texts)

# Stop measuring time and memory
end_time = time.time()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

review_token_list = [item for sublist in review_token_list for item in sublist]
review_text_list = [item for sublist in review_text_list for item in sublist]


# Print results
print(f"Execution Time: {end_time - start_time} seconds")
print(f"Current Memory Usage: {current / 10**6} MB")
print(f"Peak Memory Usage: {peak / 10**6} MB")

# Output the tokenized reviews list to verify correctness (optional)
# print(review_token_list)
# Out:
# Execution Time: 1731.2893810272217 seconds
# Current Memory Usage: 904.953882 MB
# Peak Memory Usage: 947.502712 MB

# %%
review_token_list
# Out:
# [['it',
#   'have',
#   'no',
#   'side',
#   'effect',
#   'I',
#   'take',
#   'it',
#   'in',
#   'combination',
#   'of',
#   'bystolic',
#   'mg',
#   'and',
#   'fish',
#   'oil'],
#  ['my',
#   'son',
#   'be',
#   'halfway',
#   'through',
#   'his',
#   'fourth',
#   'week',
#   'of',
#   'intuniv',
#   'we',
#   'become',
#   'concerned',
#   'when',
#   'he',
#   'begin',
#   'this',
#   'last',
#   'week',
#   'when',
#   'he',
#   'start',
#   'take',
#   'the',
#   'high',
#   'dose',
#   'he',
#   'will',
#   'be',
#   'on',
#   'for',
#   'two',
#   'day',
#   'he',
#   'could',
#   'hardly',
#   'get',
#   'out',
#   'of',
#   'bed',
#   'be',
#   'very',
#   'cranky',
#   'and',
#   'sleep',
#   'for',
#   'nearly',
#   'hour',
#   'on',
#   'a',
#   'drive',
#   'home',
#   'from',
#   'school',
#   'vacation',
#   'very',
#   'unusual',
#   'for',
#   'he',
#   'I',
#   'call',
#   'his',
#   'doctor',
#   'on',
#   'monday',
#   'morning',
#   'and',
#   'she',
#   'say',
#   'to',
#   'stick',
#   'it',
#   'out',
#   'a',
#   'few',
#   'day',
#   'see',
#   'how',
#   'he',
#   'do',
#   'at',
#   'school',
#   'and',
#   'with',
#   'get',
#   'up',
#   'in',
#   'the',
#   'morning',
#   'the',
#   'last',
#   'two',
#   'day',
#   'have',
#   'be',
#   'problem',
#   'free',
#   'he',
#   'be',
#   'much',
#   'more',
#   'agreeable',
#   'than',
#   'ever',
#   'he',
#   'be',
#   'less',
#   'emotional',
#   'a',
#   'good',
#   'thing',
#   'less',
#   'cranky',
#   'he',
#   'be',
#   'remember',
#   'all',
#   'the',
#   'thing',
#   'he',
#   'should',
#   'overall',
#   'his',
#   'behavior',
#   'be',
#   'well',
#   'we',
#   'have',
#   'try',
#   'many',
#   'different',
#   'medication',
#   'and',
#   'so',
#   'far',
#   'this',
#   'be',
#   'the',
#   'most',
#   'effective'],
#  ['I',
#   'use',
#   'to',
#   'take',
#   'another',
#   'oral',
#   'contraceptive',
#   'which',
#   'have',
#   'pill',
#   'cycle',
#   'and',
#   'be',
#   'very',
#   'happy',
#   'very',
#   'light',
#   'period',
#   'max',
#   'day',
#   'no',
#   'other',
#   'side',
#   'effect',
#   'but',
#   'it',
#   'contain',
#   'hormone',
#   'gestodene',
#   'which',
#   'be',
#   'not',
#   'available',
#   'in',
#   'we',
#   'so',
#   'I',
#   'switch',
#   'to',
#   'lybrel',
#   'because',
#   'the',
#   'ingredient',
#   'be',
#   'similar',
#   'when',
#   'my',
#   'other',
#   'pill',
#   'end',
#   'I',
#   'start',
#   'lybrel',
#   'immediately',
#   'on',
#   'my',
#   'first',
#   'day',
#   'of',
#   'period',
#   'as',
#   'the',
#   'instruction',
#   'say',
#   'and',
#   'the',
#   'period',
#   'last',
#   'for',
#   'two',
#   'week',
#   'when',
#   'take',
#   'the',
#   'second',
#   'pack',
#   'same',
#   'two',
#   'week',
#   'and',
#   'now',
#   'with',
#   'third',
#   'pack',
#   'thing',
#   'get',
#   'even',
#   'bad',
#   'my',
#   'third',
#   'period',
#   'last',
#   'for',
#   'two',
#   'week',
#   'and',
#   'now',
#   'its',
#   'the',
#   'end',
#   'of',
#   'the',
#   'third',
#   'week',
#   'I',
#   'still',
#   'have',
#   'daily',
#   'brown',
#   'discharge',
#   'the',
#   'positive',
#   'side',
#   'be',
#   'that',
#   'I',
#   'do',
#   'not',
#   'have',
#   'any',
#   'other',
#   'side',
#   'effect',
#   'the',
#   'idea',
#   'of',
#   'be',
#   'period',
#   'free',
#   'be',
#   'so',
#   'tempting',
#   'alas'],
#  ['this',
#   'be',
#   'my',
#   'first',
#   'time',
#   'use',
#   'any',
#   'form',
#   'of',
#   'birth',
#   'control',
#   'I',
#   'm',
#   'glad',
#   'I',
#   'go',
#   'with',
#   'the',
#   'patch',
#   'I',
#   'have',
#   'be',
#   'on',
#   'it',
#   'for',
#   'month',
#   'at',
#   'first',
#   'it',
#   'decrease',
#   'my',
#   'libido',
#   'but',
#   'that',
#   'subside',
#   'the',
#   'only',
#   'downside',
#   'be',
#   'that',
#   'it',
#   'make',
#   'my',
#   'period',
#   'long',
#   'day',
#   'to',
#   'be',
#   'exact',
#   'I',
#   'use',
#   'to',
#   'only',
#   'have',
#   'period',
#   'for',
#   'day',
#   'max',
#   'also',
#   'make',
#   'my',
#   'cramp',
#   'intense',
#   'for',
#   'the',
#   'first',
#   'two',
#   'day',
#   'of',
#   'my',
#   'period',
#   'I',
#   'never',
#   'have',
#   'cramp',
#   'before',
#   'use',
#   'birth',
#   'control',
#   'other',
#   'than',
#   'that',
#   'in',
#   'happy',
#   'with',
#   'the',
#   'patch'],
#  ['suboxone',
#   'have',
#   'completely',
#   'turn',
#   'my',
#   'life',
#   'around',
#   'I',
#   'feel',
#   'healthy',
#   'I',
#   'm',
#   'excel',
#   'at',
#   'my',
#   'job',
#   'and',
#   'I',
#   'always',
#   'have',
#   'money',
#   'in',
#   'my',
#   'pocket',
#   'and',
#   'my',
#   'saving',
#   'account',
#   'I',
#   'have',
#   'none',
#   'of',
#   'those',
#   'before',
#   'suboxone',
#   'and',
#   'spend',
#   'year',
#   'abuse',
#   'oxycontin',
#   'my',
#   'paycheck',
#   'be',
#   'already',
#   'spend',
#   'by',
#   'the',
#   'time',
#   'I',
#   'get',
#   'it',
#   'and',
#   'I',
#   'start',
#   'resort',
#   'to',
#   'scheme',
#   'and',
#   'steal',
#   'to',
#   'fund',
#   'my',
#   'addiction',
#   'all',
#   'that',
#   'be',
#   'history',
#   'if',
#   'you',
#   're',
#   'ready',
#   'to',
#   'stop',
#   'there',
#   's',
#   'a',
#   'good',
#   'chance',
#   'that',
#   'suboxone',
#   'will',
#   'put',
#   'you',
#   'on',
#   'the',
#   'path',
#   'of',
#   'great',
#   'life',
#   'again',
#   'I',
#   'have',
#   'find',
#   'the',
#   'sideeffect',
#   'to',
#   'be',
#   'minimal',
#   'compare',
#   'to',
#   'oxycontin',
#   'I',
#   'm',
#   'actually',
#   'sleep',
#   'well',
#   'slight',
#   'constipation',
#   'be',
#   'about',
#   'it',
#   'for',
#   'I',
#   'it',
#   'truly',
#   'be',
#   'amazing',
#   'the',
#   'cost',
#   'pale',
#   'in',
#   'comparison',
#   'to',
#   'what',
#   'I',
#   'spend',
#   'on',
#   'oxycontin'],
#  ['2nd',
#   'day',
#   'on',
#   '5',
#   'mg',
#   'start',
#   'to',
#   'work',
#   'with',
#   'rock',
#   'hard',
#   'erection',
#   'however',
#   'experiance',
#   'headache',
#   'low',
#   'bowel',
#   'preassure',
#   '3rd',
#   'day',
#   'erection',
#   'would',
#   'wake',
#   'I',
#   'up',
#   'amp',
#   'hurt',
#   'legankle',
#   'ache',
#   'severe',
#   'low',
#   'bowel',
#   'preassure',
#   'like',
#   'you',
#   'need',
#   'to',
#   'go',
#   'but',
#   'can',
#   'not',
#   'enjoy',
#   'the',
#   'initial',
#   'rockhard',
#   'erection',
#   'but',
#   'not',
#   'at',
#   'these',
#   'side',
#   'effect',
#   'or',
#   'for',
#   'month',
#   'supply',
#   'I',
#   'm',
#   'amp',
#   'work',
#   'out',
#   '3xs',
#   'a',
#   'week',
#   'not',
#   'worth',
#   'side',
#   'effect'],
#  ['he',
#   'pull',
#   'out',
#   'but',
#   'he',
#   'cumme',
#   'a',
#   'bit',
#   'in',
#   'I',
#   'I',
#   'take',
#   'the',
#   'plan',
#   'b',
#   'hour',
#   'later',
#   'and',
#   'take',
#   'a',
#   'pregnancy',
#   'test',
#   'two',
#   'week',
#   'later',
#   'I',
#   'm',
#   'pregnant'],
#  ['abilify',
#   'change',
#   'my',
#   'life',
#   'there',
#   'be',
#   'hope',
#   'I',
#   'be',
#   'on',
#   'zoloft',
#   'and',
#   'clonidine',
#   'when',
#   'I',
#   'first',
#   'start',
#   'abilify',
#   'at',
#   'the',
#   'age',
#   'of',
#   'zoloft',
#   'for',
#   'depression',
#   'and',
#   'clondine',
#   'to',
#   'manage',
#   'my',
#   'complete',
#   'rage',
#   'my',
#   'mood',
#   'be',
#   'out',
#   'of',
#   'control',
#   'I',
#   'be',
#   'depressed',
#   'and',
#   'hopeless',
#   'one',
#   'second',
#   'and',
#   'then',
#   'mean',
#   'irrational',
#   'and',
#   'full',
#   'of',
#   'rage',
#   'the',
#   'next',
#   'my',
#   'dr',
#   'prescribe',
#   'I',
#   '2',
#   'mg',
#   'of',
#   'abilify',
#   'and',
#   'from',
#   'that',
#   'point',
#   'on',
#   'I',
#   'feel',
#   'like',
#   'I',
#   'have',
#   'be',
#   'cure',
#   'though',
#   'I',
#   'know',
#   'I',
#   'm',
#   'not',
#   'bipolar',
#   'disorder',
#   'be',
#   'a',
#   'constant',
#   'battle',
#   'I',
#   'know',
#   'abilify',
#   'work',
#   'for',
#   'I',
#   'because',
#   'I',
#   'have',
#   'try',
#   'to',
#   'get',
#   'off',
#   'it',
#   'and',
#   'lose',
#   'complete',
#   'control',
#   'over',
#   'my',
#   'emotion',
#   'go',
#   'back',
#   'on',
#   'it',
#   'and',
#   'I',
#   'be',
#   'golden',
#   'again',
#   'I',
#   'be',
#   'on',
#   '5',
#   'mg',
#   '2x',
#   'daily',
#   'I',
#   'be',
#   'now',
#   'and',
#   'well',
#   'than',
#   'I',
#   'have',
#   'ever',
#   'be',
#   'in',
#   'the',
#   'past',
#   'only',
#   'side',
#   'effect',
#   'be',
#   'I',
#   'like',
#   'to',
#   'eat',
#   'a',
#   'lot'],
#  ['I',
#   've',
#   'have',
#   'nothing',
#   'but',
#   'problem',
#   'with',
#   'the',
#   'keppera',
#   'constant',
#   'shake',
#   'in',
#   'my',
#   'arm',
#   'amp',
#   'leg',
#   'amp',
#   'pin',
#   'amp',
#   'needle',
#   'feel',
#   'in',
#   'my',
#   'arm',
#   'amp',
#   'leg',
#   'severe',
#   'light',
#   'headedness',
#   'no',
#   'appetite',
#   'amp',
#   'etc'],
#  ['I',
#   'have',
#   'be',
#   'on',
#   'the',
#   'pill',
#   'for',
#   'many',
#   'year',
#   'when',
#   'my',
#   'doctor',
#   'change',
#   'my',
#   'rx',
#   'to',
#   'chateal',
#   'it',
#   'be',
#   'as',
#   'effective',
#   'it',
#   'really',
#   'do',
#   'help',
#   'I',
#   'by',
#   'completely',
#   'clear',
#   'my',
#   'acne',
#   'this',
#   'take',
#   'about',
#   'month',
#   'though',
#   'I',
#   'do',
#   'not',
#   'gain',
#   'extra',
#   'weight',
#   'or',
#   'develop',
#   'any',
#   'emotional',
#   'health',
#   'issue',
#   'I',
#   'stop',
#   'take',
#   'it',
#   'bc',
#   'I',
#   'start',
#   'use',
#   'a',
#   'more',
#   'natural',
#   'method',
#   'of',
#   'birth',
#   'control',
#   'but',
#   'start',
#   'to',
#   'take',
#   'it',
#   'bc',
#   'I',
#   'hate',
#   'that',
#   'my',
#   'acne',
#   'come',
#   'back',
#   'at',
#   'age',
#   'I',
#   'really',
#   'hope',
#   'symptom',
#   'like',
#   'depression',
#   'or',
#   'weight',
#   'gain',
#   'do',
#   'not',
#   'begin',
#   'to',
#   'affect',
#   'I',
#   'as',
#   'I',
#   'be',
#   'old',
#   'now',
#   'I',
#   'm',
#   'also',
#   'naturally',
#   'moody',
#   'so',
#   'this',
#   'may',
#   'worsen',
#   'thing',
#   'I',
#   'be',
#   'in',
#   'a',
#   'negative',
#   'mental',
#   'rut',
#   'today',
#   'also',
#   'I',
#   'hope',
#   'this',
#   'do',
#   'not',
#   'push',
#   'I',
#   'over',
#   'the',
#   'edge',
#   'as',
#   'I',
#   'believe',
#   'I',
#   'be',
#   'depress',
#   'hopefully',
#   'it',
#   'll',
#   'be',
#   'just',
#   'like',
#   'when',
#   'I',
#   'be',
#   'young'],
#  ['I',
#   'have',
#   'be',
#   'on',
#   'this',
#   'medication',
#   'almost',
#   'two',
#   'week',
#   'start',
#   'out',
#   'on',
#   '25',
#   'mg',
#   'and',
#   'work',
#   'my',
#   'way',
#   'up',
#   'to',
#   '100',
#   'mg',
#   'currently',
#   'at',
#   '50',
#   'mg',
#   'no',
#   'headache',
#   'at',
#   'all',
#   'so',
#   'far',
#   'and',
#   'I',
#   'be',
#   'have',
#   'crippling',
#   'migraine',
#   'a',
#   'week',
#   'I',
#   'have',
#   'lose',
#   '2lb',
#   'so',
#   'far',
#   'but',
#   'note',
#   'I',
#   'be',
#   'really',
#   'pay',
#   'close',
#   'attention',
#   'to',
#   'what',
#   'I',
#   'be',
#   'eat',
#   'I',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'weight',
#   'to',
#   'lose',
#   'and',
#   'if',
#   'weight',
#   'loss',
#   'be',
#   'a',
#   'side',
#   'effect',
#   'I',
#   'want',
#   'to',
#   'help',
#   'it',
#   'along',
#   'as',
#   'much',
#   'as',
#   'I',
#   'can',
#   'now',
#   'other',
#   'side',
#   'effect',
#   'they',
#   'be',
#   'there',
#   'the',
#   'word',
#   'recall',
#   'issue',
#   'exist',
#   'the',
#   'memory',
#   'issue',
#   'the',
#   'bad',
#   'of',
#   'it',
#   'seem',
#   'to',
#   'be',
#   'the',
#   'vision',
#   'disturbance',
#   'there',
#   'have',
#   'be',
#   'time',
#   'I',
#   'have',
#   'just',
#   'not',
#   'drive',
#   'because',
#   'I',
#   'm',
#   'sure',
#   'it',
#   'would',
#   'not',
#   'have',
#   'be',
#   'safe',
#   'the',
#   'good',
#   'news',
#   'be',
#   'it',
#   'seem',
#   'to',
#   'be',
#   'wear',
#   'offi',
#   'have',
#   'ton',
#   'of',
#   'energy',
#   'and',
#   'I',
#   'be',
#   'in',
#   'a',
#   'great',
#   'mood'],
#  ['I',
#   'have',
#   'take',
#   'antidepressant',
#   'for',
#   'year',
#   'with',
#   'some',
#   'improvement',
#   'but',
#   'mostly',
#   'moderate',
#   'to',
#   'severe',
#   'side',
#   'affect',
#   'which',
#   'make',
#   'I',
#   'go',
#   'off',
#   'they',
#   'I',
#   'only',
#   'take',
#   'cymbalta',
#   'now',
#   'mostly',
#   'for',
#   'pain',
#   'when',
#   'I',
#   'begin',
#   'deplin',
#   'I',
#   'notice',
#   'a',
#   'major',
#   'improvement',
#   'overnight',
#   'more',
#   'energy',
#   'well',
#   'disposition',
#   'and',
#   'no',
#   'sinking',
#   'to',
#   'the',
#   'low',
#   'low',
#   'of',
#   'major',
#   'depression',
#   'I',
#   'have',
#   'be',
#   'take',
#   'it',
#   'for',
#   'about',
#   'month',
#   'now',
#   'and',
#   'feel',
#   'like',
#   'a',
#   'normal',
#   'person',
#   'for',
#   'the',
#   'first',
#   'time',
#   'ever',
#   'good',
#   'thing',
#   'no',
#   'side',
#   'effect'],
#  ['I',
#   'have',
#   'crohns',
#   'with',
#   'a',
#   'resection',
#   'year',
#   'ago',
#   'and',
#   'have',
#   'be',
#   'mostly',
#   'in',
#   'remission',
#   'since',
#   'have',
#   'recently',
#   'have',
#   'a',
#   'bad',
#   'flare',
#   'and',
#   'narrow',
#   'at',
#   'the',
#   'anastomosis',
#   'and',
#   'need',
#   'to',
#   'be',
#   'on',
#   'medication',
#   'but',
#   'have',
#   'not',
#   'find',
#   'one',
#   'that',
#   'I',
#   'can',
#   'handle',
#   'asacol',
#   'give',
#   'I',
#   'such',
#   'serious',
#   'body',
#   'aching',
#   'and',
#   'fatigue',
#   'that',
#   'I',
#   'could',
#   'not',
#   'function',
#   'pentasa',
#   'immediately',
#   'give',
#   'I',
#   'heart',
#   'palpitation',
#   'and',
#   'arrhythmias',
#   'so',
#   'I',
#   'have',
#   'to',
#   'discontinue',
#   'it'],
#  ['have',
#   'a',
#   'little',
#   'bit',
#   'of',
#   'a',
#   'linger',
#   'cough',
#   'from',
#   'a',
#   'cold',
#   'not',
#   'give',
#   'I',
#   'much',
#   'trouble',
#   'except',
#   'keep',
#   'I',
#   'up',
#   'at',
#   'night',
#   'I',
#   'hear',
#   'this',
#   'be',
#   'good',
#   'so',
#   'I',
#   'take',
#   'so',
#   'I',
#   'could',
#   'get',
#   'some',
#   'sleep',
#   'help',
#   'tremendously',
#   'with',
#   'the',
#   'cough',
#   'but',
#   'then',
#   'I',
#   'be',
#   'have',
#   'bad',
#   'stomach',
#   'cramp',
#   'and',
#   'diarrhea',
#   'I',
#   'have',
#   'not',
#   'eat',
#   'anything',
#   'that',
#   'should',
#   'have',
#   'upset',
#   'my',
#   'stomach',
#   'and',
#   'it',
#   'do',
#   'not',
#   'really',
#   'feel',
#   'like',
#   'a',
#   'quotbugquot',
#   'so',
#   'I',
#   'look',
#   'up',
#   'side',
#   'effect',
#   'for',
#   'delsym',
#   'now',
#   'I',
#   'wish',
#   'I',
#   'have',
#   'do',
#   'that',
#   'first',
#   'because',
#   'I',
#   'probably',
#   'would',
#   'not',
#   'have',
#   'take',
#   'it',
#   'so',
#   'while',
#   'it',
#   'work',
#   'for',
#   'my',
#   'cough',
#   'I',
#   'still',
#   'do',
#   'not',
#   'get',
#   'any',
#   'sleep',
#   'due',
#   'to',
#   'the',
#   'stomach',
#   'issue'],
#  ['start',
#   'nexplanon',
#   'month',
#   'ago',
#   'because',
#   'I',
#   'have',
#   'a',
#   'minimal',
#   'amount',
#   'of',
#   'contraception',
#   'I',
#   'can',
#   'take',
#   'due',
#   'to',
#   'my',
#   'inability',
#   'to',
#   'take',
#   'the',
#   'hormone',
#   'that',
#   'be',
#   'use',
#   'in',
#   'most',
#   'birth',
#   'control',
#   'I',
#   'm',
#   'try',
#   'to',
#   'give',
#   'it',
#   'time',
#   'because',
#   'it',
#   'be',
#   'one',
#   'of',
#   'my',
#   'only',
#   'option',
#   'right',
#   'now',
#   'but',
#   'honestly',
#   'if',
#   'I',
#   'have',
#   'option',
#   'I',
#   'd',
#   'get',
#   'it',
#   'remove',
#   'I',
#   've',
#   'never',
#   'have',
#   'acne',
#   'problem',
#   'in',
#   'my',
#   'life',
#   'and',
#   'immediately',
#   'break',
#   'out',
#   'after',
#   'get',
#   'it',
#   'implant',
#   'sex',
#   'drive',
#   'be',
#   'completely',
#   'go',
#   'and',
#   'I',
#   'use',
#   'to',
#   'have',
#   'sex',
#   'with',
#   'my',
#   'boyfriend',
#   'a',
#   'few',
#   'day',
#   'a',
#   'week',
#   'now',
#   'its',
#   'completely',
#   'force',
#   'and',
#   'not',
#   'even',
#   'fun',
#   'for',
#   'I',
#   'anymore',
#   'I',
#   'mean',
#   'I',
#   'm',
#   'on',
#   'birth',
#   'control',
#   'because',
#   'I',
#   'like',
#   'have',
#   'sex',
#   'but',
#   'do',
#   'not',
#   'want',
#   'to',
#   'get',
#   'pregnant',
#   'why',
#   'take',
#   'a',
#   'birth',
#   'control',
#   'that',
#   'take',
#   'away',
#   'sex',
#   'very',
#   'unhappy',
#   'and',
#   'hope',
#   'that',
#   'I',
#   'get',
#   'it',
#   'back',
#   'with',
#   'time',
#   'or',
#   'I',
#   'm',
#   'get',
#   'it',
#   'remove'],
#  ['I',
#   'have',
#   'be',
#   'take',
#   'saxenda',
#   'since',
#   'july',
#   'I',
#   'have',
#   'severe',
#   'nausea',
#   'for',
#   'about',
#   'a',
#   'month',
#   'once',
#   'I',
#   'get',
#   'up',
#   'to',
#   'the',
#   'dosage',
#   'it',
#   'have',
#   'since',
#   'subside',
#   'and',
#   'the',
#   'only',
#   'side',
#   'effect',
#   'I',
#   'notice',
#   'now',
#   'be',
#   'the',
#   'dry',
#   'mouth',
#   'I',
#   'make',
#   'sure',
#   'to',
#   'drink',
#   'litre',
#   'of',
#   'water',
#   'a',
#   'day',
#   'about',
#   'glass',
#   'this',
#   'help',
#   'with',
#   'the',
#   'weight',
#   'loss',
#   'as',
#   'well',
#   'as',
#   'the',
#   'constipation',
#   'I',
#   'have',
#   'be',
#   'reduce',
#   'my',
#   'dose',
#   'to',
#   'find',
#   'a',
#   'comfortable',
#   'spot',
#   'where',
#   'I',
#   'be',
#   'still',
#   'lose',
#   'weight',
#   'but',
#   'do',
#   'not',
#   'feel',
#   'like',
#   'I',
#   'be',
#   'over',
#   'medicate',
#   'for',
#   'I',
#   'be',
#   'work',
#   'very',
#   'well',
#   'I',
#   'also',
#   'feel',
#   'wear',
#   'a',
#   'fitbit',
#   'have',
#   'really',
#   'help',
#   'I',
#   'can',
#   'track',
#   'my',
#   'food',
#   'water',
#   'exercise',
#   'and',
#   'step',
#   'it',
#   'keep',
#   'I',
#   'move',
#   'more',
#   'when',
#   'this',
#   'start',
#   'I',
#   'could',
#   'barely',
#   'walk',
#   'the',
#   'length',
#   'of',
#   'myself',
#   'without',
#   'getting',
#   'wind',
#   'I',
#   'have',
#   'lose',
#   'lbs',
#   'so',
#   'far'],
#  ['this',
#   'drug',
#   'work',
#   'very',
#   'well',
#   'for',
#   'I',
#   'and',
#   'clear',
#   'up',
#   'my',
#   'uti',
#   'in',
#   'a',
#   'matter',
#   'of',
#   '48hrs',
#   'although',
#   'I',
#   'be',
#   'on',
#   'a',
#   'day',
#   'course',
#   'of',
#   '2x200mgdaily',
#   'unfortunately',
#   'once',
#   'the',
#   'tablet',
#   'finish',
#   'the',
#   'infection',
#   'return',
#   'so',
#   'need',
#   'a',
#   '2nd',
#   'course',
#   'I',
#   'm',
#   'currently',
#   'take',
#   'a',
#   'low',
#   'dose',
#   'at',
#   'evening',
#   'to',
#   'keep',
#   'the',
#   'infection',
#   'at',
#   'bay',
#   'while',
#   'the',
#   'specialist',
#   'do',
#   'some',
#   'test',
#   'I',
#   'normally',
#   'get',
#   'every',
#   'side',
#   'effect',
#   'go',
#   'and',
#   'dread',
#   'take',
#   'new',
#   'medication',
#   'in',
#   'any',
#   'form',
#   'especially',
#   'after',
#   'an',
#   'horrific',
#   'experience',
#   'with',
#   'ciorofloxacin',
#   'but',
#   'the',
#   'only',
#   'side',
#   'effect',
#   'I',
#   'experience',
#   'with',
#   'this',
#   'be',
#   'itchy',
#   'ankle',
#   'and',
#   'foot',
#   'on',
#   'day',
#   'two',
#   'but',
#   'that',
#   'do',
#   'not',
#   'last',
#   'into',
#   'third',
#   'day',
#   'so',
#   'I',
#   'would',
#   'class',
#   'this',
#   'as',
#   'a',
#   'minor',
#   'side',
#   'effect',
#   'and',
#   'insignificant',
#   'good',
#   'luck'],
#  ['I',
#   've',
#   'be',
#   'take',
#   'amitriptyline',
#   'since',
#   'january',
#   'after',
#   'be',
#   'diagnose',
#   'with',
#   'fibromyalgia',
#   'I',
#   'try',
#   'cymbalta',
#   'for',
#   'a',
#   'week',
#   'and',
#   'my',
#   'dr',
#   'decide',
#   'that',
#   'since',
#   'it',
#   'keep',
#   'I',
#   'awake',
#   'that',
#   'it',
#   'be',
#   'not',
#   'a',
#   'good',
#   'fit',
#   'for',
#   'I',
#   'even',
#   'though',
#   'it',
#   'relieve',
#   'my',
#   'pain',
#   'I',
#   'start',
#   'with',
#   'mg',
#   'after',
#   'week',
#   'I',
#   'have',
#   'some',
#   'breakthrough',
#   'pain',
#   'so',
#   'my',
#   'dr',
#   'increase',
#   'my',
#   'dosage',
#   'to',
#   '50',
#   'mg',
#   'and',
#   'I',
#   'm',
#   'still',
#   'on',
#   'that',
#   'dosage',
#   'today',
#   'for',
#   'the',
#   'first',
#   'full',
#   'year',
#   'I',
#   'be',
#   'on',
#   'this',
#   'I',
#   'never',
#   'have',
#   'pain',
#   'and',
#   'felt',
#   'cure',
#   'as',
#   'time',
#   'go',
#   'on',
#   'it',
#   'seem',
#   'to',
#   'help',
#   'control',
#   'my',
#   'pain',
#   'I',
#   'do',
#   'still',
#   'have',
#   'pain',
#   'but',
#   'at',
#   'a',
#   'low',
#   'manageable',
#   'level',
#   'I',
#   'take',
#   'this',
#   'around',
#   '7',
#   'pm',
#   'each',
#   'evening',
#   'to',
#   'avoid',
#   'feel',
#   'overly',
#   'drowsy',
#   'in',
#   'the',
#   'morning',
#   'this',
#   'med',
#   'allow',
#   'I',
#   'to',
#   'have',
#   'a',
#   'fairly',
#   'normal',
#   'life'],
#  ['I',
#   've',
#   'be',
#   'on',
#   'every',
#   'medicine',
#   'under',
#   'the',
#   'sun',
#   'it',
#   'seem',
#   'to',
#   'manage',
#   'the',
#   'hypomania',
#   'mania',
#   'of',
#   'bipolar2',
#   'within',
#   'a',
#   'few',
#   'day',
#   'of',
#   'start',
#   'lamictal',
#   'be',
#   'on',
#   'tegretol',
#   'it',
#   'be',
#   'as',
#   'if',
#   'someone',
#   'have',
#   'turn',
#   'a',
#   'light',
#   'on',
#   'in',
#   'my',
#   'head',
#   'be',
#   'this',
#   'the',
#   'way',
#   'quotnormalquot',
#   'people',
#   'think',
#   'be',
#   'one',
#   'of',
#   'the',
#   'first',
#   'thing',
#   'that',
#   'strike',
#   'I',
#   'I',
#   'sleep',
#   'like',
#   'a',
#   'log',
#   'have',
#   'no',
#   'irritability',
#   'almost',
#   'no',
#   'anger',
#   'other',
#   'than',
#   'what',
#   'would',
#   'be',
#   'consider',
#   'normal',
#   'I',
#   'be',
#   'able',
#   'to',
#   'focus',
#   'and',
#   'my',
#   'creative',
#   'impulsive',
#   'thought',
#   'have',
#   'decrease',
#   'enough',
#   'to',
#   'be',
#   'manageable',
#   'its',
#   'a',
#   'god',
#   'send',
#   'as',
#   'I',
#   'would',
#   'perennially',
#   'be',
#   'in',
#   'a',
#   'state',
#   'of',
#   'hypo',
#   'mania',
#   'which',
#   'sound',
#   'great',
#   'but',
#   'I',
#   'be',
#   'physically',
#   'and',
#   'emotionally',
#   'exhaust',
#   'my',
#   'libido',
#   'be',
#   'markedly',
#   'low',
#   'but',
#   'I',
#   'wonder',
#   'if',
#   'that',
#   'be',
#   'perhaps',
#   'an',
#   'effect',
#   'of',
#   'not',
#   'be',
#   'hypo',
#   'manic',
#   'I',
#   'take',
#   'mg',
#   'for',
#   'anxiety'],
#  ['I',
#   'have',
#   'be',
#   'on',
#   'tasigna',
#   'for',
#   'just',
#   'over',
#   'year',
#   'now',
#   '300',
#   'mg',
#   'x',
#   'time',
#   'a',
#   'day',
#   'tasigna',
#   'work',
#   'for',
#   'I',
#   'within',
#   'a',
#   'few',
#   'week',
#   'I',
#   'have',
#   'be',
#   'in',
#   'remission',
#   'for',
#   'basically',
#   'the',
#   'entire',
#   'year',
#   'as',
#   'for',
#   'the',
#   'side',
#   'effect',
#   'I',
#   'feel',
#   'sick',
#   'to',
#   'my',
#   'stomach',
#   'tire',
#   'severe',
#   'leg',
#   'and',
#   'arm',
#   'pain',
#   'I',
#   'can',
#   'not',
#   'walk',
#   'to',
#   'long',
#   'without',
#   'need',
#   'a',
#   'break',
#   'I',
#   'go',
#   'from',
#   'work',
#   'full',
#   'time',
#   'to',
#   'not',
#   'work',
#   'at',
#   'all',
#   'because',
#   'I',
#   'be',
#   'so',
#   'tired',
#   'all',
#   'the',
#   'time',
#   'but',
#   'hey',
#   'I',
#   'be',
#   'in',
#   'remission',
#   'and',
#   'alive',
#   'so',
#   'be',
#   'all',
#   'the',
#   'above',
#   'really',
#   'a',
#   'problem',
#   'nope'],
#  ['spring',
#   'of',
#   'I',
#   'be',
#   'hospitalize',
#   'with',
#   'pnuemonia',
#   'and',
#   'diagnose',
#   'with',
#   'lyme',
#   'diease',
#   'and',
#   'full',
#   'blow',
#   'aid',
#   'with',
#   'cd4',
#   'count',
#   'of',
#   'quotquot',
#   'viral',
#   'load',
#   'some',
#   'number',
#   'so',
#   'high',
#   'in',
#   'the',
#   'million',
#   'I',
#   'could',
#   'never',
#   'remember',
#   'I',
#   'be',
#   'take',
#   'combivir',
#   'and',
#   'kaletra',
#   'with',
#   'dapsone',
#   'for',
#   'the',
#   '1st',
#   'year',
#   'then',
#   'it',
#   'stop',
#   'work',
#   'I',
#   'start',
#   'kaletra',
#   'with',
#   'the',
#   'dapsone',
#   'my',
#   'cd4',
#   'count',
#   'be',
#   'now',
#   'and',
#   'rise',
#   'for',
#   'a',
#   'few',
#   'week',
#   'I',
#   'be',
#   'very',
#   'aggressive',
#   'and',
#   'break',
#   'all',
#   'my',
#   'dish',
#   'in',
#   'the',
#   'house',
#   'lol',
#   'I',
#   'take',
#   'vitamin',
#   'supplement',
#   'and',
#   'drink',
#   'a',
#   'boost',
#   'pluz',
#   'every',
#   'day',
#   'life',
#   'be',
#   'good',
#   'now'],
#  ['I',
#   'have',
#   'insomnia',
#   'its',
#   'horrible',
#   'my',
#   'story',
#   'begin',
#   'with',
#   'my',
#   'pcp',
#   'prescribe',
#   'I',
#   'prozac',
#   'to',
#   'help',
#   'with',
#   'intestinal',
#   'issue',
#   'because',
#   'I',
#   'be',
#   'desperate',
#   'I',
#   'try',
#   'it',
#   'I',
#   'be',
#   'on',
#   'it',
#   'for',
#   'week',
#   'stop',
#   'because',
#   'of',
#   'insomnia',
#   'then',
#   'I',
#   'be',
#   'prescribe',
#   'ativan',
#   'it',
#   'out',
#   'I',
#   'out',
#   'but',
#   'be',
#   'very',
#   'addict',
#   'I',
#   'have',
#   'rebound',
#   'insomnia',
#   'then',
#   'after',
#   'about',
#   'day',
#   'I',
#   'hardly',
#   'any',
#   'sleep',
#   'l',
#   'try',
#   'the',
#   'doctor',
#   'one',
#   'more',
#   'time',
#   'I',
#   'ask',
#   'he',
#   'about',
#   'trazadone',
#   'he',
#   'tell',
#   'I',
#   'that',
#   'be',
#   'a',
#   'good',
#   'medication',
#   'for',
#   'insomnia',
#   'he',
#   'put',
#   'I',
#   'on',
#   'mgs',
#   'but',
#   'state',
#   'I',
#   'may',
#   'have',
#   'to',
#   'figure',
#   'out',
#   'what',
#   'dosage',
#   'be',
#   'good',
#   'for',
#   'I',
#   'I',
#   'be',
#   'currently',
#   'take',
#   'mgs',
#   'which',
#   'be',
#   'on',
#   'the',
#   'low',
#   'range',
#   'of',
#   'what',
#   'be',
#   'prescribe',
#   'mgs',
#   'be',
#   'at',
#   'the',
#   'high',
#   'end',
#   'for',
#   'insomnia',
#   'I',
#   'have',
#   'the',
#   'dry',
#   'mouth',
#   'and',
#   'nasel',
#   'congestion',
#   'I',
#   'can',
#   'live',
#   'with',
#   'that',
#   'I',
#   'sleep',
#   'now',
#   'yeah'],
#  ['nexplanon',
#   'do',
#   'its',
#   'job',
#   'I',
#   'can',
#   'have',
#   'worry',
#   'free',
#   'sex',
#   'the',
#   'only',
#   'thing',
#   'be',
#   'that',
#   'my',
#   'period',
#   'be',
#   'sometimes',
#   'light',
#   'and',
#   'sometimes',
#   'heavy',
#   'sometimes',
#   'they',
#   'go',
#   'away',
#   'and',
#   'sometimes',
#   'they',
#   'show',
#   'up',
#   'unexpected',
#   'I',
#   'also',
#   'feel',
#   'somewhat',
#   'depressed',
#   'not',
#   'sure',
#   'if',
#   'its',
#   'nexplanon',
#   'or',
#   'not',
#   'I',
#   've',
#   'have',
#   'nexplanont',
#   'for',
#   'about',
#   'month',
#   'now',
#   'but',
#   'despite',
#   'the',
#   'side',
#   'effect',
#   'its',
#   'the',
#   'most',
#   'effective',
#   'birth',
#   'control',
#   'I',
#   've',
#   'ever',
#   'use',
#   'and',
#   'I',
#   'do',
#   'not',
#   'plan',
#   'on',
#   'take',
#   'it',
#   'out'],
#  ['I',
#   'live',
#   'in',
#   'western',
#   'australia',
#   'and',
#   'disturb',
#   'by',
#   'some',
#   'comment',
#   'on',
#   'here',
#   'the',
#   'cost',
#   'of',
#   'embrel',
#   'be',
#   'cost',
#   'of',
#   'an',
#   'ordinary',
#   'prescription',
#   'for',
#   'I',
#   'the',
#   'government',
#   'pay',
#   'the',
#   'remainder',
#   'of',
#   'the',
#   'cost',
#   'to',
#   'the',
#   'chemist',
#   'I',
#   'also',
#   'go',
#   'to',
#   'the',
#   'the',
#   'medical',
#   'centre',
#   'every',
#   'saturday',
#   'morning',
#   'a',
#   'dr',
#   'look',
#   'over',
#   'my',
#   'prescription',
#   'and',
#   'then',
#   'he',
#   'advise',
#   'the',
#   'nurse',
#   'to',
#   'administer',
#   'the',
#   'injection',
#   'also',
#   'no',
#   'cost',
#   'to',
#   'myself',
#   'and',
#   'this',
#   'be',
#   'part',
#   'of',
#   'nurse',
#   'duty',
#   'I',
#   'be',
#   'unsure',
#   'of',
#   'the',
#   'country',
#   'where',
#   'people',
#   'who',
#   'have',
#   'make',
#   'comment',
#   'refer',
#   'to',
#   'cost',
#   'and',
#   'that',
#   'nobody',
#   'be',
#   'there',
#   'to',
#   'administer',
#   'the',
#   'injection',
#   'for',
#   'they',
#   'I',
#   'be',
#   'very',
#   'lucky',
#   'to',
#   'live',
#   'in',
#   'australia',
#   'as',
#   'we',
#   'have',
#   'the',
#   'good',
#   'health',
#   'system',
#   'worldwide',
#   'and',
#   'everybody',
#   'be',
#   'give',
#   'the',
#   'opportunity',
#   'to',
#   'receive',
#   'proper',
#   'medical',
#   'help',
#   'whether',
#   'you',
#   'be',
#   'rich',
#   'or',
#   'poor',
#   'there',
#   'be',
#   'no',
#   'discrimination'],
#  ['do',
#   'not',
#   'use',
#   'the',
#   'cream',
#   'that',
#   'come',
#   'with',
#   'this',
#   'it',
#   'turn',
#   'my',
#   'hooha',
#   'into',
#   'a',
#   'burn',
#   'ring',
#   'of',
#   'fire',
#   'it',
#   'be',
#   'be',
#   'and',
#   'I',
#   'have',
#   'to',
#   'work',
#   'tomorrow',
#   'its',
#   'go',
#   'to',
#   'be',
#   'a',
#   'sleepless',
#   'night',
#   'for',
#   'I'],
#  ['be',
#   'prescribe',
#   'one',
#   'dose',
#   'over',
#   'the',
#   'course',
#   'of',
#   'one',
#   'day',
#   'take',
#   'pill',
#   'of',
#   '250',
#   'mg',
#   'after',
#   'a',
#   'light',
#   'lunch',
#   'and',
#   'have',
#   'nausea',
#   'and',
#   'mild',
#   'stomach',
#   'painsupset',
#   'lie',
#   'down',
#   'do',
#   'not',
#   'alleviate',
#   'the',
#   'discomfort',
#   'and',
#   'throw',
#   'up',
#   'hour',
#   'later',
#   'call',
#   'up',
#   'my',
#   'doctor',
#   'to',
#   'check',
#   'if',
#   'I',
#   'need',
#   'to',
#   'take',
#   'another',
#   'dose',
#   'but',
#   'he',
#   'say',
#   'my',
#   'body',
#   'would',
#   'have',
#   'absorb',
#   'the',
#   'pill',
#   'by',
#   'then',
#   'still',
#   'experience',
#   'mild',
#   'stomach',
#   'pain',
#   'but',
#   'nausea',
#   'be',
#   'mostly',
#   'go',
#   'now'],
#  ['I',
#   'm',
#   'write',
#   'a',
#   'second',
#   'review',
#   'on',
#   'vaniqa',
#   'I',
#   'start',
#   'use',
#   'this',
#   'in',
#   'february',
#   'this',
#   'year',
#   'twice',
#   'a',
#   'day',
#   'although',
#   'some',
#   'daystime',
#   'I',
#   'do',
#   'forget',
#   'I',
#   'just',
#   'want',
#   'to',
#   'say',
#   'how',
#   'delighted',
#   'I',
#   'be',
#   'to',
#   'have',
#   'find',
#   'this',
#   'it',
#   'have',
#   'totally',
#   'and',
#   'completely',
#   'change',
#   'my',
#   'life',
#   'I',
#   'have',
#   'terrible',
#   'male',
#   'pattern',
#   'hair',
#   'growth',
#   'all',
#   'over',
#   'my',
#   'cheek',
#   'chin',
#   'upper',
#   'and',
#   'low',
#   'lip',
#   'and',
#   'start',
#   'to',
#   'grow',
#   'down',
#   'my',
#   'neck',
#   'I',
#   'use',
#   'to',
#   'pluck',
#   'for',
#   'up',
#   'to',
#   'hrs',
#   'a',
#   'time',
#   'every',
#   '3rd',
#   'day',
#   'but',
#   'be',
#   'never',
#   'hair',
#   'free',
#   'I',
#   'would',
#   'not',
#   'kiss',
#   'anyone',
#   'hello',
#   'or',
#   'goodbye',
#   'as',
#   'even',
#   'pluck',
#   'the',
#   'stubble',
#   'could',
#   'be',
#   'feel',
#   'under',
#   'my',
#   'skin',
#   'month',
#   'on',
#   'I',
#   'm',
#   'not',
#   'scared',
#   'of',
#   'be',
#   'catch',
#   'in',
#   'bright',
#   'sunlight',
#   'I',
#   'pluck',
#   'around',
#   'once',
#   'a',
#   'fortnight',
#   'and',
#   'it',
#   'take',
#   'around',
#   'min',
#   'the',
#   'hair',
#   'that',
#   'be',
#   'come',
#   'through',
#   'be',
#   'soft',
#   'and',
#   'downy',
#   'my',
#   'life',
#   'be',
#   'transform'],
#  ['hi',
#   'all',
#   'my',
#   'son',
#   'who',
#   'be',
#   'be',
#   'diagnose',
#   'when',
#   'he',
#   'be',
#   'in',
#   '2nd',
#   'grade',
#   'we',
#   'try',
#   'everything',
#   'before',
#   'medication',
#   'when',
#   'we',
#   'try',
#   'med',
#   'the',
#   'first',
#   'one',
#   'make',
#   'he',
#   'loose',
#   'weight',
#   'fast',
#   'the',
#   'second',
#   'give',
#   'he',
#   'a',
#   'nasty',
#   'tic',
#   'that',
#   'thankfully',
#   'go',
#   'away',
#   'as',
#   'soon',
#   'as',
#   'he',
#   'stop',
#   'the',
#   'med',
#   'the',
#   'third',
#   'work',
#   'for',
#   'a',
#   'couple',
#   'of',
#   'year',
#   'and',
#   'around',
#   'january',
#   'of',
#   'last',
#   'year',
#   'we',
#   'start',
#   'to',
#   'have',
#   'problem',
#   'so',
#   'his',
#   'doctor',
#   'recommend',
#   'daytrana',
#   'it',
#   'have',
#   'be',
#   'wonderful',
#   'for',
#   'my',
#   'son',
#   'easy',
#   'to',
#   'use',
#   'he',
#   'handle',
#   'this',
#   'for',
#   'himself',
#   'each',
#   'day',
#   'and',
#   'take',
#   'it',
#   'off',
#   'when',
#   'he',
#   'get',
#   'home',
#   'from',
#   'school',
#   'the',
#   'patch',
#   'effect',
#   'last',
#   'long',
#   'enough',
#   'for',
#   'he',
#   'to',
#   'do',
#   'his',
#   'homework',
#   'he',
#   'do',
#   'have',
#   'issue',
#   'with',
#   'weight',
#   'gain',
#   'and',
#   'sleep',
#   'but',
#   'he',
#   'use',
#   'melatonin',
#   'before',
#   'bed',
#   'if',
#   'he',
#   'feel',
#   'like',
#   'he',
#   'will',
#   'not',
#   'be',
#   'able',
#   'to',
#   'shut',
#   'down',
#   'the',
#   'shortage',
#   'be',
#   'kill',
#   'we'],
#  ['honestly',
#   'I',
#   'have',
#   'be',
#   'take',
#   'ativan',
#   'for',
#   'year',
#   'now',
#   '1',
#   'mg',
#   'twice',
#   'daily',
#   'it',
#   'do',
#   'help',
#   'but',
#   'it',
#   'should',
#   'be',
#   'use',
#   'as',
#   'a',
#   'tool',
#   'for',
#   'panic',
#   'attack',
#   'not',
#   'a',
#   'solution',
#   'I',
#   'have',
#   'try',
#   'so',
#   'many',
#   'antidepressant',
#   'as',
#   'well',
#   'such',
#   'as',
#   'cymbalta',
#   'cipralex',
#   'and',
#   'a',
#   'couple',
#   'more',
#   'the',
#   'good',
#   'thing',
#   'be',
#   'to',
#   'talk',
#   'to',
#   'close',
#   'friend',
#   'and',
#   'family',
#   'or',
#   'even',
#   'a',
#   'psychiatrist',
#   'talk',
#   'to',
#   'people',
#   'and',
#   'venting',
#   'be',
#   'honestly',
#   'the',
#   'good',
#   'thing',
#   'you',
#   'can',
#   'do',
#   'for',
#   'yourself',
#   'even',
#   'though',
#   'it',
#   'take',
#   'a',
#   'lot',
#   'of',
#   'will',
#   'power',
#   'to',
#   'do',
#   'it',
#   'I',
#   'would',
#   'love',
#   'to',
#   'hear',
#   'other',
#   'people',
#   'opinion'],
#  ['at',
#   'first',
#   'I',
#   'suffer',
#   'through',
#   'they',
#   'this',
#   'include',
#   'splitting',
#   'head',
#   'pain',
#   'nausea',
#   'and',
#   'vomiting',
#   'I',
#   'start',
#   'use',
#   'excedrin',
#   'after',
#   'a',
#   'while',
#   'which',
#   'help',
#   'if',
#   'I',
#   'take',
#   'it',
#   'right',
#   'away',
#   'then',
#   'that',
#   'start',
#   'to',
#   'not',
#   'work',
#   'so',
#   'well',
#   'anymore',
#   'I',
#   'have',
#   'one',
#   'really',
#   'bad',
#   'one',
#   'that',
#   'last',
#   'hour',
#   'I',
#   'be',
#   'still',
#   'throw',
#   'up',
#   'at',
#   'pm',
#   'and',
#   'I',
#   'be',
#   'now',
#   'throw',
#   'up',
#   'blood',
#   'I',
#   'go',
#   'to',
#   'the',
#   'er',
#   'and',
#   'when',
#   'I',
#   'finally',
#   'get',
#   'in',
#   'they',
#   'put',
#   'I',
#   'on',
#   'an',
#   'iv',
#   'to',
#   'hydrate',
#   'I',
#   'they',
#   'then',
#   'add',
#   'imitrex',
#   'to',
#   'the',
#   'bag',
#   'and',
#   'I',
#   'soon',
#   'start',
#   'feel',
#   'side',
#   'effect',
#   'my',
#   'head',
#   'feel',
#   'like',
#   'I',
#   'be',
#   'go',
#   'to',
#   'pass',
#   'out',
#   'my',
#   'breathing',
#   'became',
#   'labored',
#   'and',
#   'it',
#   'feel',
#   'like',
#   'someone',
#   'be',
#   'sit',
#   'on',
#   'my',
#   'chest',
#   'they',
#   'say',
#   'that',
#   'mean',
#   'it',
#   'be',
#   'work',
#   'after',
#   'about',
#   'two',
#   'minute',
#   'everything',
#   'be',
#   'go',
#   'I',
#   'get',
#   'pill',
#   'to',
#   'take',
#   'at',
#   'home',
#   'and',
#   'they',
#   'work',
#   'okay',
#   'not',
#   'as',
#   'fast'],
#  ['very', 'good', 'response', 'it', 'be', 'so', 'useful', 'for', 'I'],
#  ['week',
#   'on',
#   'zoloft',
#   'for',
#   'anxiety',
#   'and',
#   'mood',
#   'swing',
#   'I',
#   'take',
#   '50',
#   'mg',
#   'in',
#   'the',
#   'morning',
#   'with',
#   'my',
#   'breakfast',
#   'nausea',
#   'on',
#   'day',
#   'one',
#   'but',
#   'that',
#   'subside',
#   'as',
#   'the',
#   'week',
#   'go',
#   'on',
#   'I',
#   'get',
#   'the',
#   'jitter',
#   'about',
#   'hrs',
#   'after',
#   'take',
#   'it',
#   'follow',
#   'by',
#   'yawn',
#   'I',
#   'feel',
#   'much',
#   'well',
#   'though',
#   'and',
#   'less',
#   'angrystressed'],
#  ['I',
#   'be',
#   'year',
#   'old',
#   'I',
#   'have',
#   'a',
#   'multiple',
#   'composite',
#   'spinal',
#   'injury',
#   'year',
#   'ago',
#   'the',
#   'ache',
#   'and',
#   'pain',
#   'unbearable',
#   'I',
#   'start',
#   'take',
#   'antiinflammatorie',
#   'about',
#   'year',
#   'ago',
#   'I',
#   'start',
#   'get',
#   'injection',
#   'every',
#   'month',
#   'of',
#   'toradol',
#   'and',
#   'quotdepoquot',
#   'something',
#   'I',
#   'be',
#   'almost',
#   'off',
#   'all',
#   'pain',
#   'med',
#   'I',
#   'mean',
#   'I',
#   'still',
#   'have',
#   'bad',
#   'day',
#   'but',
#   'I',
#   'can',
#   'function',
#   'again'],
#  ['the',
#   'burning',
#   'be',
#   'out',
#   'of',
#   'control',
#   'about',
#   'minute',
#   'after',
#   'insert',
#   'it',
#   'sit',
#   'in',
#   'the',
#   'bath',
#   'try',
#   'to',
#   'get',
#   'this',
#   'stuff',
#   'out',
#   'this',
#   'be',
#   'awful'],
#  ['have',
#   'be',
#   'take',
#   'viberzi',
#   'for',
#   'a',
#   'month',
#   'now',
#   'for',
#   'ibsd',
#   'and',
#   'I',
#   'can',
#   'not',
#   'be',
#   'happy',
#   'I',
#   'have',
#   'zero',
#   'side',
#   'effect',
#   'thank',
#   'you',
#   'for',
#   'make',
#   'I',
#   'normal',
#   'again'],
#  ['reduce',
#   'my',
#   'pain',
#   'by',
#   'and',
#   'let',
#   'I',
#   'live',
#   'a',
#   'normal',
#   'life',
#   'again'],
#  ['so',
#   'much',
#   'pain',
#   'in',
#   'the',
#   'last',
#   'year',
#   'I',
#   'have',
#   'suffer',
#   'with',
#   'a',
#   'brain',
#   'tumour',
#   'so',
#   'have',
#   'be',
#   'in',
#   'a',
#   'lot',
#   'of',
#   'pain',
#   'to',
#   'the',
#   'point',
#   'of',
#   'morphine',
#   'everyday',
#   'for',
#   'a',
#   'year',
#   'then',
#   'I',
#   'have',
#   'brain',
#   'surgerybut',
#   'the',
#   'pain',
#   'from',
#   'this',
#   'pill',
#   'come',
#   'pretty',
#   'close',
#   'in',
#   'serious',
#   'pain',
#   'to',
#   'the',
#   'point',
#   'of',
#   'black',
#   'out',
#   'hot',
#   'and',
#   'cold',
#   'shiver',
#   'and',
#   'just',
#   'sit',
#   'in',
#   'pain',
#   'feel',
#   'like',
#   'trap',
#   'windindigestion',
#   'its',
#   'just',
#   'ahhhh',
#   'do',
#   'not',
#   'take',
#   'this'],
#  ['I',
#   'have',
#   'be',
#   'on',
#   'morphine',
#   'for',
#   'at',
#   'least',
#   'yearsit',
#   'be',
#   'the',
#   'only',
#   'medicine',
#   'that',
#   'seem',
#   'to',
#   'manage',
#   'my',
#   'pain',
#   'without',
#   'it',
#   'I',
#   'would',
#   'be',
#   'in',
#   'bed',
#   'of',
#   'the',
#   'time',
#   'with',
#   'it',
#   'I',
#   'can',
#   'have',
#   'a',
#   'life'],
#  ['I',
#   'have',
#   'take',
#   'this',
#   'at',
#   'least',
#   'time',
#   'for',
#   'the',
#   'last',
#   'year',
#   'I',
#   'have',
#   'have',
#   'major',
#   'problem',
#   'with',
#   'it',
#   'since',
#   'the',
#   'first',
#   'time',
#   'cause',
#   'I',
#   'major',
#   'fatigue',
#   'the',
#   'last',
#   'time',
#   'I',
#   'take',
#   'it',
#   'be',
#   'year',
#   'ago',
#   'and',
#   'I',
#   'have',
#   'very',
#   'severe',
#   'cramp',
#   'and',
#   'not',
#   'have',
#   'enough',
#   'time',
#   'to',
#   'get',
#   'to',
#   'the',
#   'bathroom',
#   'I',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'and',
#   'the',
#   'doctor',
#   'say',
#   'it',
#   'do',
#   'not',
#   'work',
#   'good',
#   'enough',
#   'so',
#   'he',
#   'have',
#   'I',
#   'go',
#   'home',
#   'and',
#   'do',
#   'a',
#   'second',
#   'round',
#   'I',
#   'go',
#   'back',
#   'the',
#   'next',
#   'day',
#   'and',
#   'do',
#   'the',
#   'process',
#   'with',
#   'no',
#   'energy',
#   'I',
#   'have',
#   'to',
#   'do',
#   'it',
#   'last',
#   'night',
#   'and',
#   'it',
#   'be',
#   'even',
#   'bad',
#   'than',
#   'the',
#   'other',
#   'time',
#   'I',
#   'be',
#   'gag',
#   'it',
#   'down',
#   'and',
#   'up',
#   'all',
#   'night',
#   'with',
#   'severe',
#   'cramp',
#   'I',
#   'try',
#   'the',
#   'second',
#   'dose',
#   'in',
#   'the',
#   'morning',
#   'and',
#   'I',
#   'just',
#   'about',
#   'start',
#   'throw',
#   'up',
#   'so',
#   'I',
#   'call',
#   'the',
#   'office',
#   'and',
#   'they',
#   'say',
#   'to',
#   'stop',
#   'once',
#   'the',
#   'doctor',
#   'be',
#   'do',
#   'he',
#   'say',
#   'it',
#   'do',
#   'not',
#   'evacuate',
#   'enough'],
#  ['I',
#   'have',
#   'a',
#   'similar',
#   'experience',
#   'tremor',
#   'in',
#   'hand',
#   'not',
#   'really',
#   'noticeable',
#   'to',
#   'someone',
#   'watch',
#   'unless',
#   'they',
#   'be',
#   'look',
#   'for',
#   'it',
#   'but',
#   'relief',
#   'from',
#   'the',
#   'delusion',
#   'I',
#   'be',
#   'experience',
#   'my',
#   'problem',
#   'have',
#   'be',
#   'go',
#   'on',
#   'for',
#   'over',
#   'year',
#   'so',
#   'I',
#   'anticipate',
#   'it',
#   'will',
#   'not',
#   'magically',
#   'disappear',
#   'and',
#   'it',
#   'do',
#   'not',
#   'but',
#   'the',
#   'clarity',
#   'of',
#   'thinking',
#   'I',
#   'experience',
#   'with',
#   'this',
#   'medicine',
#   'really',
#   'help',
#   'I'],
#  ['I',
#   'be',
#   'very',
#   'prone',
#   'to',
#   'yeast',
#   'infection',
#   'I',
#   'believe',
#   'its',
#   'due',
#   'to',
#   'my',
#   'birth',
#   'control',
#   'as',
#   'well',
#   'as',
#   'have',
#   'unprotected',
#   'sex',
#   'fluconazole',
#   'have',
#   'always',
#   'clear',
#   'up',
#   'my',
#   'yeast',
#   'infection',
#   'with',
#   'dose',
#   'no',
#   'side',
#   'effect'],
#  ['I',
#   'be',
#   'just',
#   'finish',
#   'my',
#   'second',
#   'week',
#   'take',
#   'contrave',
#   'and',
#   'have',
#   'lose',
#   'lbs',
#   'it',
#   'have',
#   'be',
#   'an',
#   'interesting',
#   'experience',
#   'because',
#   'the',
#   'drug',
#   'be',
#   'definitely',
#   'not',
#   'an',
#   'appetite',
#   'suppressant',
#   'yet',
#   'it',
#   'do',
#   'help',
#   'you',
#   'control',
#   'the',
#   'urge',
#   'to',
#   'eat',
#   'I',
#   'have',
#   'have',
#   'mild',
#   'side',
#   'effect',
#   'some',
#   'stomach',
#   'discomfort',
#   'and',
#   'slight',
#   'headache',
#   'along',
#   'with',
#   'constipation',
#   'but',
#   'it',
#   'have',
#   'all',
#   'be',
#   'easily',
#   'manageable',
#   'if',
#   'you',
#   'be',
#   'consider',
#   'take',
#   'this',
#   'medication',
#   'please',
#   'keep',
#   'in',
#   'mind',
#   'that',
#   'you',
#   'still',
#   'need',
#   'to',
#   'do',
#   'the',
#   'work',
#   'by',
#   'exercise',
#   'and',
#   'eat',
#   'right',
#   'but',
#   'the',
#   'medication',
#   'really',
#   'do',
#   'help',
#   'it',
#   'have',
#   'help',
#   'I',
#   'get',
#   'my',
#   'motivation',
#   'back',
#   'to',
#   'exercise',
#   'and',
#   'it',
#   'definitely',
#   'help',
#   'with',
#   'craving',
#   'to',
#   'eat',
#   'make',
#   'it',
#   'easy',
#   'to',
#   'just',
#   'eat',
#   'what',
#   'I',
#   'need',
#   'to',
#   'be',
#   'healthy',
#   'use',
#   'the',
#   'coupon',
#   'they',
#   'give',
#   'you',
#   'it',
#   'drop',
#   'cost',
#   'to'],
#  ['this',
#   'medication',
#   'change',
#   'my',
#   'life',
#   'my',
#   'panic',
#   'attack',
#   'be',
#   'so',
#   'out',
#   'of',
#   'control',
#   'I',
#   'be',
#   'barely',
#   'able',
#   'to',
#   'leave',
#   'the',
#   'house',
#   'within',
#   'day',
#   'a',
#   'moderate',
#   'doe',
#   'of',
#   'this',
#   'change',
#   'I',
#   'into',
#   'a',
#   'new',
#   'person',
#   'that',
#   'be',
#   'year',
#   'ago',
#   'my',
#   'dosage',
#   'have',
#   'never',
#   'change'],
#  ['I',
#   'have',
#   'be',
#   'take',
#   'this',
#   'medicine',
#   'due',
#   'to',
#   'lower',
#   'back',
#   'trouble',
#   'when',
#   'I',
#   'first',
#   'take',
#   'it',
#   'it',
#   'work',
#   'great',
#   'now',
#   'all',
#   'it',
#   'do',
#   'be',
#   'put',
#   'I',
#   'to',
#   'sleep'],
#  ['my',
#   'gp',
#   'start',
#   'I',
#   'on',
#   'venlafaxine',
#   'yesterday',
#   'to',
#   'help',
#   'with',
#   'depression',
#   'and',
#   'the',
#   'changea',
#   'hour',
#   'after',
#   'take',
#   'they',
#   'I',
#   'be',
#   'feel',
#   'very',
#   'sick',
#   'could',
#   'not',
#   'stomach',
#   'food',
#   'or',
#   'fluid',
#   'think',
#   'keep',
#   'it',
#   'up',
#   'as',
#   'she',
#   'tell',
#   'I',
#   'they',
#   'do',
#   'come',
#   'with',
#   'some',
#   'side',
#   'effect',
#   'which',
#   'would',
#   'get',
#   'bettertook',
#   'another',
#   'one',
#   'last',
#   'night',
#   'and',
#   'be',
#   'so',
#   'ill',
#   'I',
#   'could',
#   'not',
#   'stand',
#   'be',
#   'sick',
#   'sweating',
#   'shake',
#   'thought',
#   'I',
#   'be',
#   'go',
#   'to',
#   'pass',
#   'out',
#   'do',
#   'get',
#   'some',
#   'sleep',
#   'hope',
#   'to',
#   'feel',
#   'well',
#   'this',
#   'morningtook',
#   'another',
#   'one',
#   'and',
#   'feel',
#   'so',
#   'space',
#   'out',
#   'dry',
#   'mouth',
#   'shake',
#   'sick',
#   'so',
#   'book',
#   'in',
#   'to',
#   'see',
#   'gp',
#   'again',
#   'to',
#   'make',
#   'sure',
#   'I',
#   'should',
#   'be',
#   'feel',
#   'like',
#   'this',
#   'only',
#   'to',
#   'find',
#   'out',
#   'she',
#   'have',
#   'put',
#   'I',
#   'on',
#   'the',
#   'wrong',
#   'dose',
#   'should',
#   'have',
#   'be',
#   'on',
#   '5',
#   'mg',
#   'be',
#   'put',
#   'on',
#   '150',
#   'mg',
#   'now',
#   'on',
#   'right',
#   'dose',
#   'hope',
#   'this',
#   'will',
#   'be',
#   'well'],
#  ['at',
#   'initial',
#   'testing',
#   'my',
#   'vl',
#   'be',
#   'over',
#   'million',
#   'I',
#   'receive',
#   'my',
#   'med',
#   'on',
#   'saturday',
#   'day',
#   'prior',
#   'to',
#   'testing',
#   'to',
#   'establish',
#   'a',
#   'baseline',
#   'I',
#   'start',
#   'when',
#   'I',
#   'receive',
#   'my',
#   'pill',
#   'day',
#   'and',
#   'hour',
#   'later',
#   'I',
#   'get',
#   'my',
#   'blood',
#   'test',
#   'to',
#   'establish',
#   'vl',
#   'I',
#   'have',
#   'take',
#   'pill',
#   'at',
#   'this',
#   'point',
#   'and',
#   'my',
#   'vl',
#   'be',
#   'under',
#   'vl',
#   'week',
#   'be',
#   'vl',
#   'week',
#   'be',
#   'and',
#   'week',
#   'be',
#   'week',
#   'til',
#   'my',
#   '1st',
#   'eot',
#   'test',
#   'I',
#   'feel',
#   'cure',
#   'my',
#   'side',
#   'effect',
#   'be',
#   'next',
#   'to',
#   'nothing'],
#  ['side',
#   'effect',
#   'be',
#   'light',
#   'fatigue',
#   'and',
#   'a',
#   'bit',
#   'of',
#   'a',
#   'headache',
#   'I',
#   'do',
#   'find',
#   'it',
#   'easy',
#   'to',
#   'take',
#   'it',
#   'an',
#   'hour',
#   'after',
#   'dinner',
#   'way',
#   'well',
#   'then',
#   'the',
#   'triplethreat',
#   'approach',
#   'my',
#   'blood',
#   'work',
#   'do',
#   'indicate',
#   'that',
#   'I',
#   'be',
#   'in',
#   'the',
#   'beggining',
#   'stage',
#   'of',
#   'cirrhosis',
#   'I',
#   'also',
#   'have',
#   'hep',
#   'b',
#   'in',
#   'so',
#   'far',
#   'its',
#   'like',
#   'a',
#   'miracle',
#   'other',
#   'than',
#   'the',
#   'fatigue',
#   'which',
#   'be',
#   'nothing',
#   'if',
#   'you',
#   've',
#   'suffer',
#   'jaundice',
#   'or',
#   'the',
#   'sickie',
#   'symptom',
#   'that',
#   'hep',
#   'c',
#   'can',
#   'cause',
#   'its',
#   'business',
#   'as',
#   'usual'],
#  ['help',
#   'against',
#   'sadness',
#   'and',
#   'strongly',
#   'counter',
#   'moderate',
#   'urge',
#   'to',
#   'drink',
#   'at',
#   'a',
#   'stressful',
#   'confusing',
#   'time',
#   'in',
#   'my',
#   'life'],
#  ['year',
#   'old',
#   'male',
#   'uk',
#   'normally',
#   'I',
#   'would',
#   'go',
#   'every',
#   'hour',
#   'even',
#   'when',
#   'drink',
#   'very',
#   'small',
#   'amount',
#   'of',
#   'water',
#   'or',
#   'drink',
#   'I',
#   'take',
#   'this',
#   'medication',
#   'for',
#   'only',
#   'two',
#   'week',
#   'I',
#   'notice',
#   'right',
#   'away',
#   'I',
#   'would',
#   'go',
#   'less',
#   'often',
#   'to',
#   'the',
#   'toilet',
#   'and',
#   'it',
#   'be',
#   'much',
#   'easy',
#   'to',
#   'dispense',
#   'the',
#   'urine',
#   'unfortunately',
#   'I',
#   'have',
#   'to',
#   'stop',
#   'take',
#   'this',
#   'as',
#   'the',
#   'medication',
#   'side',
#   'effect',
#   'outweigh',
#   'the',
#   'benefit',
#   'I',
#   'find',
#   'that',
#   'I',
#   'would',
#   'have',
#   'incredibly',
#   'intense',
#   'mood',
#   'swing',
#   'aggression',
#   'feel',
#   'clumsy',
#   'and',
#   'dizzy',
#   'all',
#   'the',
#   'time',
#   'blurry',
#   'vision',
#   'memory',
#   'problem',
#   'or',
#   'mind',
#   'blank',
#   'runny',
#   'nose',
#   'weakness',
#   'tiredness',
#   'I',
#   'be',
#   'now',
#   'try',
#   'betmiga',
#   'let',
#   'see'],
#  ['I',
#   'battle',
#   'a',
#   'nasty',
#   'uti',
#   'for',
#   'over',
#   'a',
#   'month',
#   'amp',
#   'go',
#   'through',
#   'different',
#   'antibiotic',
#   'till',
#   'my',
#   'doctor',
#   'finally',
#   'give',
#   'I',
#   'this',
#   'one',
#   'make',
#   'you',
#   'terribly',
#   'sick',
#   'to',
#   'your',
#   'stomach',
#   'but',
#   'in',
#   'the',
#   'end',
#   'be',
#   'completely',
#   'worth',
#   'it',
#   'feel',
#   'completely',
#   'back',
#   'to',
#   'normal',
#   'in',
#   'day'],
#  ['hey',
#   'guy',
#   'its',
#   'be',
#   'month',
#   'since',
#   'my',
#   'last',
#   'post',
#   'as',
#   'I',
#   'want',
#   'to',
#   'give',
#   'it',
#   'a',
#   'few',
#   'month',
#   'to',
#   'see',
#   'how',
#   'this',
#   'be',
#   'go',
#   'to',
#   'work',
#   'so',
#   'I',
#   'have',
#   'be',
#   'on',
#   'trulicity',
#   'for',
#   'six',
#   'month',
#   'now',
#   'with',
#   'metformin',
#   'when',
#   'I',
#   'hit',
#   'the',
#   'five',
#   'month',
#   'period',
#   'the',
#   'diarrhea',
#   'gas',
#   'sulphur',
#   'belching',
#   'finally',
#   'subside',
#   'I',
#   'now',
#   'long',
#   'have',
#   'any',
#   'of',
#   'those',
#   'side',
#   'effect',
#   'however',
#   'I',
#   'still',
#   'have',
#   'not',
#   'lose',
#   'any',
#   'weight',
#   'at',
#   'all',
#   'but',
#   'I',
#   'think',
#   'that',
#   'be',
#   'because',
#   'when',
#   'I',
#   'first',
#   'start',
#   'trulicity',
#   'I',
#   'be',
#   'take',
#   'it',
#   'with',
#   'glimepiride',
#   'and',
#   'that',
#   'one',
#   'have',
#   'a',
#   'side',
#   'effect',
#   'of',
#   'weight',
#   'gain',
#   'so',
#   'I',
#   'think',
#   'the',
#   'two',
#   'med',
#   'be',
#   'fight',
#   'each',
#   'other',
#   'lol',
#   'I',
#   'have',
#   'be',
#   'back',
#   'on',
#   'the',
#   'metformin',
#   'with',
#   'trulicity',
#   'for',
#   'about',
#   'a',
#   'week',
#   'now',
#   'so',
#   'we',
#   'will',
#   'see',
#   'what',
#   'this',
#   'do',
#   'I',
#   'be',
#   'diagnose',
#   'as',
#   'stage',
#   'chronic',
#   'kidney',
#   'disease',
#   'ckd',
#   'so',
#   'I',
#   'be',
#   'watch',
#   'diet',
#   'closely'],
#  ['intuniv',
#   'do',
#   'not',
#   'work',
#   'for',
#   'my',
#   'son',
#   'he',
#   'be',
#   'bounce',
#   'off',
#   'the',
#   'wall',
#   'while',
#   'he',
#   'be',
#   'take',
#   'it',
#   'and',
#   'have',
#   'major',
#   'issue',
#   'in',
#   'class',
#   'it',
#   'seem',
#   'to',
#   'work',
#   'the',
#   'opposite',
#   'on',
#   'he'],
#  ['my',
#   'pain',
#   'management',
#   'doctor',
#   'put',
#   'I',
#   'on',
#   'butran',
#   'patch',
#   'about',
#   'week',
#   'ago',
#   'mg',
#   'dose',
#   'the',
#   'first',
#   'box',
#   'of',
#   'four',
#   'be',
#   'a',
#   'lifesaver',
#   'no',
#   'more',
#   'agony',
#   'at',
#   'work',
#   'able',
#   'to',
#   'sleep',
#   'do',
#   'more',
#   'in',
#   'two',
#   'weekend',
#   'than',
#   'I',
#   'have',
#   'in',
#   'two',
#   'year',
#   'I',
#   'm',
#   'hope',
#   'to',
#   'bump',
#   'up',
#   'to',
#   'the',
#   'ten',
#   'mg',
#   'dose',
#   'soon',
#   'to',
#   'cut',
#   'down',
#   'on',
#   'my',
#   'norco',
#   'I',
#   'have',
#   'have',
#   'chronic',
#   'pain',
#   'for',
#   'many',
#   'year',
#   'and',
#   'have',
#   'be',
#   'through',
#   'many',
#   'medicine',
#   'include',
#   'oxycontin',
#   'this',
#   'patch',
#   'be',
#   'the',
#   'good',
#   'so',
#   'far'],
#  ['I',
#   'get',
#   'heart',
#   'palpitation',
#   'really',
#   'bad',
#   'like',
#   'almost',
#   'constant',
#   'I',
#   'be',
#   'take',
#   'the',
#   'mcg',
#   'one',
#   'puff',
#   'twice',
#   'a',
#   'day',
#   'I',
#   'switch',
#   'to',
#   'flovemt',
#   'and',
#   'all',
#   'be',
#   'well'],
#  ['my',
#   'mother',
#   'die',
#   'from',
#   'lung',
#   'cancer',
#   'her',
#   'last',
#   'hope',
#   'of',
#   'this',
#   'medication',
#   'within',
#   'a',
#   'couple',
#   'month',
#   'she',
#   'be',
#   'go'],
#  ['abilify',
#   'mg',
#   'I',
#   'be',
#   'a',
#   'patient',
#   'diagnose',
#   'with',
#   'disorganized',
#   'schizophrenia',
#   'depression',
#   'schizoaffective',
#   'disorder',
#   'bipolar',
#   'I',
#   'have',
#   'experience',
#   'a',
#   'sensitivity',
#   'to',
#   'my',
#   'emotion',
#   'as',
#   'well',
#   'as',
#   'how',
#   'I',
#   'react',
#   'to',
#   'my',
#   'feeling',
#   'I',
#   'really',
#   'do',
#   'not',
#   'feel',
#   'out',
#   'of',
#   'the',
#   'normal',
#   'with',
#   'any',
#   'quotsexual',
#   'frustrationquotand',
#   'I',
#   'would',
#   'not',
#   'say',
#   'this',
#   'have',
#   'increaseddecrease',
#   'I',
#   'feel',
#   'less',
#   'anxious',
#   'on',
#   'the',
#   'medication',
#   'and',
#   'seemingly',
#   'more',
#   'at',
#   'ease',
#   'with',
#   'myself',
#   'when',
#   'I',
#   'take',
#   'this',
#   'medication',
#   'it',
#   'be',
#   'a',
#   'hard',
#   'step',
#   'to',
#   'have',
#   'people',
#   'tell',
#   'you',
#   'that',
#   'you',
#   'actually',
#   'do',
#   'well',
#   'on',
#   'this',
#   'pill',
#   'when',
#   'half',
#   'your',
#   'life',
#   'ago',
#   'you',
#   'do',
#   'not',
#   'have',
#   'quotmental',
#   'illnessquot',
#   'and',
#   'suddenly',
#   'you',
#   'become',
#   'someone',
#   'else',
#   'my',
#   'weight',
#   'do',
#   'fluxuate',
#   'when',
#   'on',
#   'this',
#   'drug',
#   'but',
#   'I',
#   'feel',
#   'it',
#   'be',
#   'due',
#   'to',
#   'stress',
#   'factor',
#   'outside',
#   'of',
#   'a',
#   'regular',
#   'environment',
#   'I',
#   'feel',
#   'if',
#   'you',
#   'place',
#   'yourself',
#   'in',
#   'good',
#   'surrounding',
#   'and',
#   'support',
#   'you',
#   'do',
#   'much',
#   'well',
#   'at',
#   'be',
#   'the',
#   'person',
#   'you',
#   'be',
#   'here',
#   'to',
# ...
#   'I',
#   'and',
#   'wonder',
#   'if',
#   'they',
#   'think',
#   'I',
#   'walk',
#   'silly',
#   'weird',
#   'but',
#   'true',
#   'after',
#   'a',
#   'month',
#   'on',
#   'this',
#   'medication',
#   'my',
#   'life',
#   'change',
#   'I',
#   'be',
#   'more',
#   'focused',
#   'my',
#   'mood',
#   'swing',
#   'be',
#   'not',
#   'so',
#   'sever',
#   'if',
#   'any',
#   'at',
#   'all',
#   'I',
#   'use',
#   'to',
#   'have',
#   'mood',
#   'swing',
#   'that',
#   'would',
#   'last',
#   'four',
#   'and',
#   'sometimes',
#   'six',
#   'month',
#   'at',
#   'a',
#   'time',
#   'this',
#   'medicine',
#   'change',
#   'my',
#   'life',
#   'and',
#   'I',
#   'feel',
#   'as',
#   'though',
#   'the',
#   'effect',
#   'be',
#   'life',
#   'change',
#   'even',
#   'when',
#   'I',
#   'stop',
#   'take',
#   'the',
#   'medication',
#   'I',
#   'still',
#   'feel',
#   'the',
#   'affect',
#   'from',
#   'how',
#   'I',
#   'feel',
#   'I',
#   'do',
#   'not',
#   'recommend',
#   'stop',
#   'take',
#   'the',
#   'medication',
#   'though',
#   'as',
#   'the',
#   'mood',
#   'swing',
#   'will',
#   'gradually',
#   'find',
#   'their',
#   'way',
#   'back',
#   'into',
#   'your',
#   'life',
#   'I'],
#  ['I',
#   'start',
#   'take',
#   'this',
#   'medication',
#   'as',
#   'soon',
#   'as',
#   'I',
#   'be',
#   'diagnose',
#   'with',
#   'an',
#   'inherit',
#   'seizure',
#   'disorder',
#   'although',
#   'I',
#   'have',
#   'not',
#   'have',
#   'a',
#   'seizure',
#   'ever',
#   'since',
#   'I',
#   'begin',
#   'to',
#   'take',
#   'the',
#   'medication',
#   'which',
#   'be',
#   'good',
#   'because',
#   'the',
#   'med',
#   'be',
#   'work',
#   'the',
#   'side',
#   'effect',
#   'be',
#   'horrible',
#   'I',
#   'would',
#   'often',
#   'feel',
#   'very',
#   'disorient',
#   'and',
#   'see',
#   'a',
#   'great',
#   'amount',
#   'of',
#   'weight',
#   'loss',
#   'this',
#   'may',
#   'not',
#   'apply',
#   'to',
#   'everyone',
#   'because',
#   'everyone',
#   'be',
#   'different',
#   'but',
#   'that',
#   'be',
#   'my',
#   'experience',
#   'with',
#   'this',
#   'medication'],
#  ['I',
#   'love',
#   'this',
#   'medicine',
#   'I',
#   'do',
#   'not',
#   'sweat',
#   'anymore',
#   'I',
#   'do',
#   'not',
#   'have',
#   'the',
#   'armpit',
#   'stain',
#   'I',
#   'can',
#   'wear',
#   'whatever',
#   'I',
#   'want',
#   'without',
#   'worry',
#   'about',
#   'sweating',
#   'if',
#   'you',
#   'have',
#   'excessive',
#   'sweating',
#   'you',
#   'should',
#   'try',
#   'this',
#   'product'],
#  ['on',
#   'my',
#   '3rd',
#   'week',
#   'with',
#   'no',
#   'improvement',
#   'increase',
#   'pain',
#   'swelling',
#   'and',
#   'fever',
#   'exponentially',
#   'increase',
#   'not',
#   'quotcorequot',
#   'temp',
#   'just',
#   'quothot',
#   'jointsquot',
#   'decrease',
#   'energy',
#   'frequent',
#   'headache',
#   'and',
#   'increase',
#   'depression',
#   'I',
#   'do',
#   'not',
#   'know',
#   'any',
#   'of',
#   'these',
#   'thing',
#   'could',
#   'get',
#   'bad',
#   'than',
#   'they',
#   'already',
#   'be',
#   'but',
#   'they',
#   'have',
#   'hang',
#   'in',
#   'there',
#   'because',
#   'mine',
#   'be',
#   'in',
#   'every',
#   'single',
#   'joint',
#   'and',
#   'quotunrelentingquot',
#   'I',
#   'do',
#   'not',
#   'really',
#   'have',
#   'flare',
#   'cuz',
#   'mine',
#   'be',
#   'constant',
#   'daily',
#   'and',
#   'nightly',
#   'pain',
#   'swell',
#   'the',
#   'fever'],
#  ['I',
#   'have',
#   'suffer',
#   'severe',
#   'pain',
#   'for',
#   'year',
#   'follow',
#   'a',
#   'motorcycle',
#   'accident',
#   'during',
#   'this',
#   'time',
#   'I',
#   'have',
#   'try',
#   'every',
#   'sort',
#   'of',
#   'pain',
#   'relief',
#   'available',
#   'to',
#   'I',
#   'mainly',
#   'narcotic',
#   'drug',
#   'which',
#   'I',
#   'find',
#   'as',
#   'bad',
#   'as',
#   'the',
#   'pain',
#   'itself',
#   'early',
#   'this',
#   'year',
#   'I',
#   'be',
#   'prescribe',
#   'lyrica',
#   'as',
#   'far',
#   'as',
#   'pain',
#   'relief',
#   'goesfantastic',
#   'after',
#   'a',
#   'few',
#   'month',
#   '1x',
#   '75',
#   'mg',
#   'cap',
#   'per',
#   'day',
#   'I',
#   'experience',
#   'total',
#   'confusion',
#   'and',
#   'be',
#   'unable',
#   'to',
#   'perform',
#   'my',
#   'daily',
#   'task',
#   'at',
#   'work',
#   'or',
#   'at',
#   'home',
#   'I',
#   'be',
#   'become',
#   'agitated',
#   'and',
#   'experience',
#   'suicidal',
#   'thought',
#   'thing',
#   'return',
#   'to',
#   'normal',
#   'after',
#   'a',
#   'week',
#   'or',
#   'so',
#   'of',
#   'not',
#   'take',
#   'lyrica',
#   'because',
#   'it',
#   'work',
#   'so',
#   'well',
#   'I',
#   'be',
#   'tempt',
#   'to',
#   'give',
#   'it',
#   'another',
#   'go',
#   'it',
#   'be',
#   'just',
#   'so',
#   'good',
#   'to',
#   'not',
#   'feel',
#   'the',
#   'pain',
#   'anymore'],
#  ['my',
#   'son',
#   'and',
#   'wife',
#   'both',
#   'come',
#   'down',
#   'with',
#   'bad',
#   'case',
#   'of',
#   'the',
#   'flu',
#   'and',
#   'I',
#   'start',
#   'to',
#   'experience',
#   'extreme',
#   'chest',
#   'tightness',
#   'cough',
#   'and',
#   'fever',
#   'about',
#   'five',
#   'day',
#   'later',
#   'take',
#   'my',
#   'first',
#   'dose',
#   'of',
#   'tamiflu',
#   'about',
#   'hour',
#   'after',
#   'experience',
#   'symptom',
#   'and',
#   'within',
#   'hour',
#   'be',
#   'feel',
#   'well',
#   'within',
#   'hour',
#   'be',
#   'well',
#   'no',
#   'side',
#   'effect',
#   'simply',
#   'a',
#   'miracle',
#   'drug',
#   'and',
#   'everyone',
#   'should',
#   'have',
#   'a',
#   'box',
#   'in',
#   'their',
#   'medicine',
#   'cabinet'],
#  ['I',
#   'take',
#   'this',
#   'on',
#   'top',
#   'of',
#   'take',
#   'same',
#   'for',
#   'depression',
#   'and',
#   'fatigue',
#   'ill',
#   'put',
#   'the',
#   'good',
#   'first',
#   'this',
#   'supplement',
#   'be',
#   'amazing',
#   'make',
#   'I',
#   'feel',
#   'much',
#   'more',
#   'confident',
#   'much',
#   'less',
#   'socially',
#   'anxious',
#   'and',
#   'more',
#   'able',
#   'to',
#   'be',
#   'assertive',
#   'and',
#   'have',
#   'no',
#   'fatigue',
#   'and',
#   'I',
#   'be',
#   'interested',
#   'in',
#   'thing',
#   'again',
#   'I',
#   'feel',
#   'joy',
#   'from',
#   'look',
#   'at',
#   'the',
#   'mountain',
#   'and',
#   'such',
#   'it',
#   'start',
#   'increase',
#   'my',
#   'facial',
#   'twitch',
#   'from',
#   'same',
#   'which',
#   'also',
#   'ritalin',
#   'bring',
#   'out',
#   'sjw',
#   'feel',
#   'kind',
#   'of',
#   'like',
#   'a',
#   'drug',
#   'like',
#   'ritalin',
#   'but',
#   'with',
#   'a',
#   'much',
#   'low',
#   'up',
#   'I',
#   've',
#   'get',
#   'to',
#   'say',
#   'I',
#   'feel',
#   'pretty',
#   'good',
#   'take',
#   'it',
#   'I',
#   'take',
#   '350',
#   'mg',
#   'once',
#   'in',
#   'the',
#   'morning',
#   'a',
#   'double',
#   'dose',
#   'at',
#   'and',
#   'a',
#   'single',
#   'dose',
#   'again',
#   'around',
#   'sometimes',
#   'I',
#   'will',
#   'take',
#   'another',
#   'dose',
#   'around',
#   'pm',
#   'I',
#   'feel',
#   'like',
#   'I',
#   'do',
#   'not',
#   'need',
#   'the',
#   'same',
#   'anymore',
#   'highly',
#   'recommend'],
#  ['I',
#   'be',
#   'year',
#   'old',
#   'and',
#   'on',
#   'my',
#   'third',
#   'pack',
#   'possibly',
#   'fourth',
#   'I',
#   'can',
#   'not',
#   'remember',
#   'for',
#   'sure',
#   'of',
#   'this',
#   'birth',
#   'control',
#   'the',
#   'first',
#   'two',
#   'month',
#   'be',
#   'great',
#   'I',
#   'do',
#   'not',
#   'notice',
#   'any',
#   'side',
#   'effect',
#   'and',
#   'my',
#   'period',
#   'be',
#   'normal',
#   'this',
#   'past',
#   'month',
#   'though',
#   'I',
#   've',
#   'start',
#   'to',
#   'notice',
#   'a',
#   'lot',
#   'of',
#   'nausea',
#   'and',
#   'some',
#   'headache',
#   'most',
#   'recently',
#   'my',
#   'depression',
#   'and',
#   'anxiety',
#   'have',
#   'increase',
#   'tenfold',
#   'and',
#   'go',
#   'through',
#   'the',
#   'roof',
#   'I',
#   'can',
#   'not',
#   'stop',
#   'cry',
#   'over',
#   'everything',
#   'and',
#   'I',
#   'm',
#   'a',
#   'mess',
#   'all',
#   'the',
#   'time',
#   'its',
#   'time',
#   'to',
#   'stop',
#   'this',
#   'bc',
#   'because',
#   'its',
#   'just',
#   'make',
#   'my',
#   'life',
#   'a',
#   'live',
#   'hell'],
#  ['I',
#   'just',
#   'switch',
#   'to',
#   'rythmol',
#   'from',
#   'toporal',
#   'and',
#   'be',
#   'check',
#   'it',
#   'out',
#   'my',
#   'heart',
#   'have',
#   'not',
#   'do',
#   'quotafibquot',
#   'type',
#   'thing',
#   'but',
#   'I',
#   'do',
#   'have',
#   'a',
#   'horrible',
#   'metalic',
#   'taste',
#   'that',
#   'I',
#   'wish',
#   'would',
#   'go',
#   'away',
#   'outside',
#   'of',
#   'that',
#   'it',
#   'seem',
#   'ok',
#   'so',
#   'far',
#   'let',
#   'I',
#   'know',
#   'your',
#   'thought',
#   'I',
#   'be',
#   'a',
#   'year',
#   'old',
#   'male'],
#  ['very', 'effective'],
#  ['after',
#   'my',
#   'back',
#   'surgery',
#   'lumbar',
#   'fusion',
#   'I',
#   'be',
#   'give',
#   'dilaudid',
#   'work',
#   'instantly',
#   'in',
#   'relieve',
#   'pain',
#   'the',
#   'only',
#   'downside',
#   'it',
#   'do',
#   'not',
#   'last',
#   'long'],
#  ['clear',
#   'up',
#   'my',
#   'abscess',
#   'also',
#   'I',
#   'keep',
#   'get',
#   'bacterial',
#   'vaginitis',
#   'for',
#   'a',
#   'year',
#   'straight',
#   'I',
#   'swear',
#   'my',
#   'bacterial',
#   'vaginitis',
#   'clear',
#   'up',
#   'this',
#   'actually',
#   'work',
#   'to',
#   'clear',
#   'that',
#   'up',
#   'also',
#   'I',
#   'think',
#   'my',
#   'bacterial',
#   'vaginitis',
#   'issue',
#   'be',
#   'stick',
#   'with',
#   'I',
#   'forever'],
#  ['it',
#   'work',
#   'very',
#   'good',
#   'for',
#   'sleep',
#   'as',
#   'I',
#   'have',
#   'chronic',
#   'insomnia',
#   'due',
#   'to',
#   'severe',
#   'anxiety',
#   'major',
#   'depression',
#   'I',
#   'do',
#   'not',
#   'take',
#   'it',
#   'yesterday',
#   'and',
#   'barely',
#   'sleep',
#   'good',
#   'what',
#   'I',
#   'hate',
#   'be',
#   'the',
#   'drowsy',
#   'feel',
#   'it',
#   'make',
#   'during',
#   'day',
#   'do',
#   'it',
#   'go',
#   'away',
#   'this',
#   'pill',
#   'make',
#   'my',
#   'birthday',
#   'a',
#   'fine',
#   'day',
#   'I',
#   'make',
#   'a',
#   'day',
#   'outside',
#   'feel',
#   'ok'],
#  ['background',
#   'essential',
#   'tremor',
#   'with',
#   'social',
#   'anxiety',
#   'and',
#   'ibs',
#   'I',
#   'm',
#   'naturally',
#   'very',
#   'happy',
#   'from',
#   '6mo',
#   'escitalopram',
#   '10',
#   'mg',
#   'to',
#   '1mo',
#   'viibryd',
#   '10',
#   'mg',
#   'upped',
#   'to',
#   '20',
#   'mg',
#   'viibryd',
#   'but',
#   'two',
#   'hour',
#   'in',
#   'have',
#   'panic',
#   'attack',
#   'tremor',
#   'go',
#   'back',
#   'to',
#   '10',
#   'mg',
#   'for',
#   'a',
#   '1mo',
#   'more',
#   'until',
#   'very',
#   'heavy',
#   'depression',
#   'episode',
#   'at',
#   'around',
#   'pm',
#   'till',
#   'pm',
#   'take',
#   'the',
#   'pill',
#   'at',
#   'be',
#   'appear',
#   'also',
#   'it',
#   'give',
#   'I',
#   'very',
#   'bad',
#   'diarrhea',
#   'after',
#   'eat',
#   'most',
#   'food',
#   'can',
#   'not',
#   'coldturkey',
#   'it',
#   'which',
#   'I',
#   'could',
#   'with',
#   'escitalopram',
#   'would',
#   'panicshakedepression',
#   'have',
#   'to',
#   'take',
#   'the',
#   'abuse',
#   'till',
#   'I',
#   'switch',
#   'back',
#   'escitalopram',
#   '10',
#   'mg',
#   'which',
#   'thankfully',
#   'calm',
#   'I',
#   'down',
#   'from',
#   'viibryd',
#   'withdrawal',
#   'I',
#   'do',
#   'not',
#   'feel',
#   'this',
#   'be',
#   'the',
#   'right',
#   'drug',
#   'for',
#   'happy',
#   'people',
#   'with',
#   'anxiety',
#   'it',
#   'do',
#   'more',
#   'unnecessary',
#   'antidepressant',
#   'change',
#   'than',
#   'it',
#   'do',
#   'anxiety',
#   'improvement'],
#  ['I',
#   've',
#   'be',
#   'drink',
#   'since',
#   '12yo',
#   'relapse',
#   'hard',
#   'about',
#   'week',
#   'ago',
#   'after',
#   'the',
#   'manager',
#   'at',
#   'work',
#   'have',
#   'suspect',
#   'that',
#   'I',
#   'have',
#   'be',
#   'drink',
#   'at',
#   'work',
#   'and',
#   'fire',
#   'I',
#   'I',
#   'spend',
#   'all',
#   'of',
#   'the',
#   'money',
#   'I',
#   'have',
#   'leave',
#   'in',
#   'the',
#   'bank',
#   'try',
#   'to',
#   'drink',
#   'myself',
#   'to',
#   'death',
#   'have',
#   'a',
#   'free',
#   'ride',
#   'to',
#   'law',
#   'school',
#   'and',
#   'lose',
#   'that',
#   'so',
#   'that',
#   'play',
#   'a',
#   'big',
#   'role',
#   'in',
#   'my',
#   'depressive',
#   'drinking',
#   'get',
#   'to',
#   'the',
#   'hospital',
#   'after',
#   'I',
#   'begin',
#   'go',
#   'into',
#   'withdrawal',
#   'and',
#   'they',
#   'sedate',
#   'I',
#   'and',
#   'give',
#   'I',
#   'a',
#   'librium',
#   'prescription',
#   'I',
#   'm',
#   'a',
#   'pound',
#   'male',
#   'with',
#   'bf',
#   'so',
#   'I',
#   'm',
#   'a',
#   'strong',
#   'otherwise',
#   'healthy',
#   'guy',
#   'four',
#   'mg',
#   'first',
#   'day',
#   'then',
#   'taper',
#   'down',
#   'the',
#   'second',
#   'day',
#   'decrease',
#   'each',
#   'day',
#   'by',
#   'pill',
#   'I',
#   'm',
#   'still',
#   'on',
#   'pill',
#   'at',
#   'night',
#   'you',
#   'should',
#   'exercise',
#   'when',
#   'off',
#   'to',
#   'control',
#   'cns',
#   'excitement',
#   'vivid',
#   'dream',
#   'too',
#   'save',
#   'I',
#   'too'],
#  ['I',
#   'have',
#   'be',
#   'take',
#   'ocella',
#   'now',
#   'for',
#   'about',
#   'month',
#   'and',
#   'in',
#   'those',
#   'month',
#   'I',
#   'have',
#   'experience',
#   'some',
#   'weight',
#   'loss',
#   'as',
#   'well',
#   'as',
#   'clear',
#   'skin',
#   'however',
#   'I',
#   'also',
#   'have',
#   'find',
#   'that',
#   'I',
#   'have',
#   'absolutely',
#   'no',
#   'sex',
#   'drive',
#   'I',
#   'be',
#   'only',
#   'and',
#   'before',
#   'take',
#   'ocella',
#   'I',
#   'have',
#   'enough',
#   'sex',
#   'drive',
#   'for',
#   'I',
#   'and',
#   'other',
#   'people',
#   'but',
#   'now',
#   'nothing'],
#  ['I',
#   'only',
#   'take',
#   'it',
#   'for',
#   'a',
#   'week',
#   'but',
#   'it',
#   'cause',
#   'horrible',
#   'headache',
#   'that',
#   'be',
#   'borderline',
#   'migraine',
#   'they',
#   'would',
#   'start',
#   'about',
#   'minute',
#   'after',
#   'take',
#   'the',
#   'pill',
#   'and',
#   'would',
#   'not',
#   'go',
#   'away',
#   'until',
#   'I',
#   'go',
#   'to',
#   'sleep',
#   'I',
#   'be',
#   'naseous',
#   'and',
#   'dizzy',
#   'constantly',
#   'and',
#   'I',
#   'would',
#   'be',
#   'very',
#   'warm',
#   'and',
#   'hot',
#   'it',
#   'be',
#   'also',
#   'cause',
#   'heart',
#   'burn',
#   'which',
#   'be',
#   'something',
#   'that',
#   'I',
#   've',
#   'never',
#   'have',
#   'before',
#   'take',
#   'this',
#   'pill',
#   'I',
#   'also',
#   'have',
#   'zero',
#   'interest',
#   'in',
#   'sex'],
#  ['the',
#   'product',
#   'be',
#   'work',
#   'so',
#   'well',
#   'for',
#   'my',
#   'athletic',
#   'preteen',
#   'daughter',
#   'as',
#   'she',
#   'begin',
#   'to',
#   'get',
#   'very',
#   'involved',
#   'with',
#   'sport',
#   'a',
#   'lot',
#   'of',
#   'sweat',
#   'and',
#   'acne',
#   'came',
#   'now',
#   'use',
#   'duac',
#   'her',
#   'acne',
#   'have',
#   'clear',
#   'and',
#   'be',
#   'under',
#   'control',
#   'her',
#   'face',
#   'be',
#   'not',
#   'so',
#   'oily',
#   'like',
#   'before',
#   'she',
#   'have',
#   'a',
#   'couple',
#   'of',
#   'blemish',
#   'but',
#   'nothing',
#   'at',
#   'all',
#   'like',
#   'before'],
#  ['as',
#   'a',
#   'supplement',
#   'to',
#   'levothyroxine',
#   'it',
#   'have',
#   'be',
#   'a',
#   'night',
#   'and',
#   'day',
#   'difference',
#   'I',
#   'no',
#   'long',
#   'sleep',
#   'all',
#   'the',
#   'time',
#   'and',
#   'can',
#   'think',
#   'clearly',
#   'I',
#   'actually',
#   'want',
#   'to',
#   'do',
#   'thing',
#   'now'],
#  ['this',
#   'work',
#   'great',
#   'for',
#   'my',
#   'husband',
#   'until',
#   'he',
#   'give',
#   'I',
#   'his',
#   'cold',
#   'I',
#   'use',
#   'this',
#   'medicine',
#   'and',
#   'be',
#   'somewhat',
#   'relieved',
#   'but',
#   'have',
#   'extremely',
#   'uncomfortable',
#   'gas',
#   'and',
#   'diarrhea',
#   'I',
#   'think',
#   'I',
#   'have',
#   'a',
#   'bad',
#   'strain',
#   'of',
#   'virus',
#   'and',
#   'take',
#   'the',
#   'medicine',
#   'again',
#   'the',
#   'next',
#   'day',
#   'within',
#   'min',
#   'my',
#   'stomach',
#   'problem',
#   'that',
#   'have',
#   'quit',
#   'the',
#   'night',
#   'before',
#   'return',
#   'with',
#   'a',
#   'vengeance',
#   'dextromethorphan',
#   'be',
#   'the',
#   'only',
#   'ingredient',
#   'I',
#   'have',
#   'not',
#   'use',
#   'before',
#   'without',
#   'this',
#   'reaction',
#   'unless',
#   'its',
#   'a',
#   'new',
#   'red',
#   'dye',
#   'allergy',
#   'I',
#   'm',
#   'never',
#   'take',
#   'anything',
#   'with',
#   'this',
#   'ingredient',
#   'again'],
#  ['I',
#   'have',
#   'try',
#   'almost',
#   'everything',
#   'under',
#   'the',
#   'sun',
#   'as',
#   'relate',
#   'to',
#   'acne',
#   'medicine',
#   'the',
#   'only',
#   'thing',
#   'that',
#   'work',
#   'for',
#   'I',
#   'be',
#   'aczone',
#   'I',
#   'have',
#   'only',
#   'be',
#   'use',
#   'it',
#   'for',
#   'day',
#   'now',
#   'but',
#   'my',
#   'face',
#   'have',
#   'clear',
#   'up',
#   'so',
#   'fast',
#   'I',
#   'have',
#   'never',
#   'see',
#   'my',
#   'skin',
#   'look',
#   'so',
#   'good',
#   'in',
#   'the',
#   'last',
#   'year',
#   'it',
#   'do',
#   'not',
#   'irritate',
#   'the',
#   'skin',
#   'and',
#   'go',
#   'on',
#   'very',
#   'light',
#   'and',
#   'absorb',
#   'right',
#   'in',
#   'highly',
#   'highly',
#   'recommend'],
#  ['my',
#   'thyroid',
#   'test',
#   'show',
#   'it',
#   'to',
#   'be',
#   'under',
#   'active',
#   'dr',
#   'increase',
#   'levothyroxine',
#   'to',
#   'mcg',
#   'to',
#   'be',
#   'take',
#   'two',
#   'hour',
#   'on',
#   'empty',
#   'stomach',
#   'before',
#   'I',
#   'can',
#   'eat',
#   'I',
#   'guestione',
#   'pharmacist',
#   'and',
#   'he',
#   'confirm',
#   'two',
#   'hour',
#   'wate',
#   'very',
#   'difficult',
#   'to',
#   'wait',
#   'hour',
#   'I',
#   'take',
#   'several',
#   'other',
#   'medication',
#   'what',
#   'can',
#   'I',
#   'do'],
#  ...]

# %% [markdown]
# Without using parallel processing took long time and even using nlp.pipe() didnt help.

# %% [markdown]
# ---

# %% [markdown]
# #### **Batch + Parallel processing of reviews using spaCy (using ThreadpoolExecutor)**

# %% [markdown]
# Using the parallel processing:

# %%
# import re
# import spacy
# import tracemalloc
# import time
# from concurrent.futures import ThreadPoolExecutor, as_completed

# def chunk_generator(iterable, chunk_size):
#     for i in range(0, len(iterable), chunk_size):
#         yield iterable[i:i+chunk_size]  # using yield generator method to generate data chunk on the fly and not load on in memory

# def data_stripper(text):
#     # Convert the input text to lowercase
#     text = text.lower()
#     # Remove standalone numbers
#     text = re.sub(r'\b\d+\b', '', text)
#     # Remove special characters, keeping only alphanumeric characters and spaces
#     text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
#     # Remove any extra whitespace (including newlines /n)
#     text = re.sub(r'\s+', ' ', text).strip()
#     return text  # lets think on it whether to use yield or return benefit

# def preprocess_text_spacy_pipe(chunk=None, batch_size=None, stop=False, lemmer=True, tokens= False):
#     processed_texts = []
#     for doc in nlp.pipe(chunk, batch_size=batch_size):
#         tokens = []
#         for token in doc:
#             if stop and token.is_stop:
#                 continue
#             if lemmer:
#                 tokens.append(token.lemma_)
#             else:
#                 tokens.append(token.text)
#         prepro_text = ' '.join(tokens)
#         processed_texts.append(prepro_text)
#     if tokens:
#         return tokens, processed_texts
#     else:   
#         return processed_texts

# def process_chunk(index, chunk, batch_size):
#     stripped_chunk = (data_stripper(review) for review in chunk)
#     prepro_texts = preprocess_text_spacy_pipe(stripped_chunk, batch_size=batch_size, lemmer=True)
#     return index, prepro_texts

# # Load the spaCy model
# nlp = spacy.load("en_core_web_sm")


# # Define the chunk size
# chunk_size = 100

# # Create chunks using the generator and preserve their indices
# chunks = list(enumerate(chunk_generator(review_list[:1000], chunk_size)))

# # List to store tokenized reviews
# review_token_list_parallel_proc = [None] * len(chunks)  # Preallocate list for ordered results
# review_token_list_parallel_proc_tokens = [None] * len(chunks)

# # Start measuring time and memory
# start_time = time.time()
# tracemalloc.start()

# # Use ThreadPoolExecutor for parallel processing
# with ThreadPoolExecutor() as executor:
#     # Submit tasks to the executor
#     futures = {executor.submit(process_chunk, index, chunk, 25): index for index, chunk in chunks}
    
#     # Process futures as they complete
#     for future in as_completed(futures):
#         index, result = future.result()
#         # print(f"Result for chunk {index}: {result}")
#         review_token_list_parallel_proc_tokens[index], review_token_list_parallel_proc[index] = result
#         # review_token_list_parallel_proc[index] = result
#         # print(f"Result for chunk {index}: {review_token_list_para3[index]}")

# # Stop measuring time and memory
# end_time = time.time()
# current, peak = tracemalloc.get_traced_memory()
# tracemalloc.stop()

# # Flatten the list
# # review_token_list = [item for sublist in review_token_list for item in sublist]

# # Print results
# print(f"Execution Time: {end_time - start_time} seconds")
# print(f"Current Memory Usage: {current / 10**6} MB")
# print(f"Peak Memory Usage: {peak / 10**6} MB")

# # Output the tokenized reviews list to verify correctness (optional)
# # print(review_token_list)
# Out:
# Execution Time: 5.585376024246216 seconds
# Current Memory Usage: 4.05627 MB
# Peak Memory Usage: 266.302408 MB

# %% [markdown]
# ### Note: Using `ThreadPoolExecutor` for Parallel Processing in Batch Text Preprocessing
#
# This code uses `ThreadPoolExecutor` from Python's `concurrent.futures` module to enable parallel processing of text data during batch preprocessing. Below is a brief explanation of how and why it is used:
#
# #### Purpose of Parallel Processing
# When processing large datasets, text preprocessing tasks like tokenization, lemmatization, and cleaning can be computationally intensive. Using parallel processing helps to speed up this workflow by allowing multiple chunks of data to be processed simultaneously.
#
# #### How It Works
# 1. **Chunking the Data:**
#    - The `chunk_generator` function divides the dataset into smaller chunks of a fixed size (`chunk_size`), making it easier to process the data in batches.
#    - Each chunk is processed independently.
#
# 2. **ThreadPoolExecutor Workflow:**
#    - **Task Submission:** Chunks are submitted as tasks to the thread pool using `executor.submit`, which assigns each task to a separate thread.
#    - **Asynchronous Processing:** The `as_completed` function ensures that tasks are processed as soon as they are completed, avoiding delays due to sequential execution.
#    - **Maintaining Order:** Results from threads are stored in a preallocated list using the chunk's index, preserving the original order of the dataset.
#
# 3. **Integration with Preprocessing:**
#    - Each thread processes its assigned chunk by first cleaning the data using the `data_stripper` function and then applying spaCy's `nlp.pipe` for tokenization and lemmatization.
#    - The results (tokens and processed text) are collected and combined at the end.
#
# #### Benefits of Using ThreadPoolExecutor
# - **Speedup:** By dividing the workload across multiple threads, overall execution time is reduced compared to processing the data sequentially.
# - **Efficiency:** CPU-bound tasks, such as those using spaCy (a C-optimized library), benefit from multithreading as they bypass Python's Global Interpreter Lock (GIL) to some extent.
# - **Scalability:** This approach can handle larger datasets efficiently, as each thread processes a smaller, manageable portion of the data.
#
# This method is an effective way to optimize text preprocessing workflows for large datasets, ensuring faster execution and better resource utilization.

# %%
import re
import spacy
import tracemalloc
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

def chunk_generator(iterable, chunk_size):
    for i in range(0, len(iterable), chunk_size):
        yield iterable[i:i+chunk_size]

def data_stripper(text):
    text = text.lower()
    text = re.sub(r'\b\d+\b', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def preprocess_text_spacy_pipe(chunk=None, batch_size=None, stop=False, lemmer=True, return_tokens=False):
    processed_texts = []
    all_tokens = []
    for doc in nlp.pipe(chunk, batch_size=batch_size):
        tokens = []
        for token in doc:
            if stop and token.is_stop:
                continue
            if lemmer:
                tokens.append(token.lemma_)
            else:
                tokens.append(token.text)
        prepro_text = ' '.join(tokens)
        processed_texts.append(prepro_text)
        if return_tokens:
            all_tokens.append(tokens)
    if return_tokens:
        return all_tokens, processed_texts
    else:
        return processed_texts

def process_chunk(index, chunk, batch_size, return_tokens=False, stop=False, lemmer=True):
    stripped_chunk = (data_stripper(review) for review in chunk)
    results = preprocess_text_spacy_pipe(stripped_chunk, batch_size=batch_size, lemmer=lemmer, stop=stop, return_tokens=return_tokens)
    return index, results

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Example list of reviews
# review_list = ["This is the first review.", "This is the second review.", "Another review here."] * 50

# Define the chunk size
chunk_size = 100

# Create chunks using the generator and preserve their indices
chunks = list(enumerate(chunk_generator(review_list, chunk_size)))

# List to store tokenized reviews and tokens
review_token_list_parallel_proc = [None] * len(chunks)  # Preallocate list for ordered results
review_token_list_parallel_proc_tokens = [None] * len(chunks)

# Start measuring time and memory
start_time = time.time()
tracemalloc.start()

# Use ThreadPoolExecutor for parallel processing
with ThreadPoolExecutor() as executor:
    # Submit tasks to the executor
    futures = {executor.submit(process_chunk, index, chunk, 25, return_tokens=True, stop=False, lemmer=True): index for index, chunk in chunks}
    
    # Process futures as they complete
    for future in as_completed(futures):
        index, result = future.result()
        if isinstance(result[0], list) and isinstance(result[1], list):
            review_token_list_parallel_proc_tokens[index], review_token_list_parallel_proc[index] = result
        else:
            review_token_list_parallel_proc[index] = result

# Stop measuring time and memory
end_time = time.time()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

# Flatten the list 
review_token_list_parallel_proc = [item for sublist in review_token_list_parallel_proc if sublist for item in sublist]
review_token_list_parallel_proc_tokens = [item for sublist in review_token_list_parallel_proc_tokens if sublist for item in sublist]

# Print results
print(f"Execution Time: {end_time - start_time} seconds")
print(f"Current Memory Usage: {current / 10**6} MB")
print(f"Peak Memory Usage: {peak / 10**6} MB")

# Output the tokenized reviews list to verify correctness (optional)
# print(review_token_list_parallel_proc)
# Out:
# Execution Time: 963.8470420837402 seconds
# Current Memory Usage: 909.091816 MB
# Peak Memory Usage: 1097.042576 MB

# %% [markdown]
# Only took half time to run where as the without parallel processing it was taking ~ 30minutes.

# %% [markdown]
# Now lets run the function with stop words as well:

# %%
review_token_list_parallel_proc_stpwrd = [None] * len(chunks)

# Start measuring time and memory
start_time = time.time()
tracemalloc.start()

# Use ThreadPoolExecutor for parallel processing
with ThreadPoolExecutor() as executor:
    # Submit tasks to the executor
    futures = {executor.submit(process_chunk, index, chunk, 25, return_tokens=False, stop=True, lemmer=True): index for index, chunk in chunks}
    
    # Process futures as they complete
    for future in as_completed(futures):
        index, result = future.result()
        if isinstance(result[0], list) and isinstance(result[1], list): # will not use in this case
            review_token_list_parallel_proc_tokens[index], review_token_list_parallel_proc[index] = result
        else:
            review_token_list_parallel_proc_stpwrd[index] = result

# Stop measuring time and memory
end_time = time.time()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

# %%
review_token_list_parallel_proc_stpwrd = [item for sublist in review_token_list_parallel_proc_stpwrd if sublist for item in sublist]

# %%
review_token_list_parallel_proc_stpwrd
# Out:
# ['effect combination bystolic mg fish oil',
#  'son halfway fourth week intuniv concerned begin week start take high dose day hardly bed cranky sleep nearly hour drive home school vacation unusual call doctor monday morning say stick day school get morning day problem free agreeable emotional good thing cranky remember thing overall behavior well try different medication far effective',
#  'oral contraceptive pill cycle happy light period max day effect contain hormone gestodene available switch lybrel ingredient similar pill end start lybrel immediately day period instruction say period last week take second pack week pack thing get bad period last week end week daily brown discharge positive not effect idea period free tempting alas',
#  'time form birth control m glad go patch month decrease libido subside downside period long day exact period day max cramp intense day period cramp birth control happy patch',
#  'suboxone completely turn life feel healthy m excel job money pocket saving account suboxone spend year abuse oxycontin paycheck spend time get start resort scheme steal fund addiction history ready stop s good chance suboxone path great life find sideeffect minimal compare oxycontin m actually sleep well slight constipation truly amazing cost pale comparison spend oxycontin',
#  '2nd day 5 mg start work rock hard erection experiance headache low bowel preassure 3rd day erection wake amp hurt legankle ache severe low bowel preassure like need not enjoy initial rockhard erection effect month supply m amp work 3xs week worth effect',
#  'pull cumme bit take plan b hour later take pregnancy test week later m pregnant',
#  'abilify change life hope zoloft clonidine start abilify age zoloft depression clondine manage complete rage mood control depressed hopeless second mean irrational rage dr prescribe 2 mg abilify point feel like cure know m bipolar disorder constant battle know abilify work try lose complete control emotion go golden 5 mg 2x daily well past effect like eat lot',
#  've problem keppera constant shake arm amp leg amp pin amp needle feel arm amp leg severe light headedness appetite amp etc',
#  'pill year doctor change rx chateal effective help completely clear acne take month gain extra weight develop emotional health issue stop take bc start natural method birth control start bc hate acne come age hope symptom like depression weight gain begin affect old m naturally moody worsen thing negative mental rut today hope not push edge believe depress hopefully ll like young',
#  'medication week start 25 mg work way 100 mg currently 50 mg headache far have crippling migraine week lose 2lb far note pay close attention eat lot weight lose weight loss effect want help effect word recall issue exist memory issue bad vision disturbance time drive m sure safe good news wear offi ton energy great mood',
#  'take antidepressant year improvement moderate severe affect make cymbalta pain begin deplin notice major improvement overnight energy well disposition sinking low low major depression take month feel like normal person time good thing effect',
#  'crohns resection year ago remission recently bad flare narrow anastomosis need medication not find handle asacol give body aching fatigue function pentasa immediately give heart palpitation arrhythmias discontinue',
#  'little bit linger cough cold give trouble keep night hear good take sleep help tremendously cough have bad stomach cramp diarrhea not eat upset stomach not feel like quotbugquot look effect delsym wish probably not take work cough not sleep stomach issue',
#  'suffer include splitting head pain nausea vomiting start excedrin help take right away start work anymore bad last hour throw pm throw blood go er finally get iv hydrate add imitrex bag soon start feel effect head feel like go pass breathing labored feel like sit chest say mean work minute go get pill home work okay fast',
#  'good response useful',
#  'week zoloft anxiety mood swing 50 mg morning breakfast nausea day subside week go jitter hrs take follow yawn feel well angrystressed',
#  'year old multiple composite spinal injury year ago ache pain unbearable start take antiinflammatorie year ago start get injection month toradol quotdepoquot pain med mean bad day function',
#  'burning control minute insert sit bath try stuff awful',
#  'take viberzi month ibsd not happy zero effect thank make normal',
#  'reduce pain let live normal life',
#  'pain year suffer brain tumour lot pain point morphine everyday year brain surgerybut pain pill come pretty close pain point black hot cold shiver sit pain feel like trap windindigestion ahhhh not',
#  'morphine yearsit medicine manage pain bed time life',
#  'take time year major problem time cause major fatigue time take year ago severe cramp have time bathroom go hospital doctor say not work good home second round go day process energy night bad time gag night severe cramp try second dose morning start throw call office say stop doctor say not evacuate',
#  'similar experience tremor hand noticeable watch look relief delusion experience problem go year anticipate magically disappear not clarity thinking experience medicine help',
#  'prone yeast infection believe birth control have unprotected sex fluconazole clear yeast infection dose effect',
#  'finish second week take contrave lose lbs interesting experience drug definitely appetite suppressant help control urge eat mild effect stomach discomfort slight headache constipation easily manageable consider take medication mind need work exercise eat right medication help help motivation exercise definitely help craving eat make easy eat need healthy use coupon drop cost',
#  'medication change life panic attack control barely able leave house day moderate change new person year ago dosage change',
#  'take medicine lower trouble take work great sleep',
#  'gp start venlafaxine yesterday help depression changea hour take feel sick not stomach food fluid think tell come effect bettertook night ill not stand sick sweating shake thought go pass sleep hope feel well morningtook feel space dry mouth shake sick book gp sure feel like find wrong dose 5 mg 150 mg right dose hope well',
#  'initial testing vl million receive med saturday day prior testing establish baseline start receive pill day hour later get blood test establish vl take pill point vl vl week vl week week week til 1st eot test feel cure effect',
#  'effect light fatigue bit headache find easy hour dinner way well triplethreat approach blood work indicate beggining stage cirrhosis hep b far like miracle fatigue ve suffer jaundice sickie symptom hep c cause business usual',
#  'help sadness strongly counter moderate urge drink stressful confusing time life',
#  'year old male uk normally hour drink small amount water drink take medication week notice right away toilet easy dispense urine unfortunately stop take medication effect outweigh benefit find incredibly intense mood swing aggression feel clumsy dizzy time blurry vision memory problem mind blank runny nose weakness tiredness try betmiga let',
#  'battle nasty uti month amp go different antibiotic till doctor finally give make terribly sick stomach end completely worth feel completely normal day',
#  'hey guy month post want month go work trulicity month metformin hit month period diarrhea gas sulphur belching finally subside long effect not lose weight think start trulicity take glimepiride effect weight gain think med fight lol metformin trulicity week diagnose stage chronic kidney disease ckd watch diet closely',
#  'intuniv work son bounce wall take have major issue class work opposite',
#  'pain management doctor butran patch week ago mg dose box lifesaver agony work able sleep weekend year m hope bump mg dose soon cut norco chronic pain year medicine include oxycontin patch good far',
#  'get heart palpitation bad like constant take mcg puff twice day switch flovemt',
#  'mother die lung cancer hope medication couple month go',
#  '2 mg xanax work perfectly panic attack feel come 2 mg pill take away long run panic attack',
#  'medication amazing day extremely sick start feel amazing month happy time depressive thought kind block sad thought work perfectly',
#  'liletta insert november process overall not bad numb injection help pain couple cramp stop have period month weird cramp keep feel stop month great notice clothe not fitting anymore ve gain pound despite month clean diet count calorie frequent exercise start lose hair week ago begin sprout chin hair not make feel depressed frustrated have remove day',
#  'work',
#  'recently refer endocrinologist start trulicity jardiance ve try byetta past stop sick lose weight throw day effective weight loss method recommend ve take dose trulicity mild nausea bad switch coffee green tea morning help recommend sugar level drop significantly drop guess week will not work wonder wait bit not know trulicity jardiance combo manage lose pound day',
#  'long term sufferer chronic pain fibromyalgia ddd scoliosis sciatica arthritis migraine chronic fatigue syndrome start counter med move prescription motrin day trip rendering numerous anti depressant doctor begin prescribe vicodin work 3month go doctor tell proceed work long month long story short ms contin 60 mg x time day 100 mg bedtime breakthru pain oxycodone 30 mg x m life',
#  'accurate information',
#  'diagnose adult onset diabete dec start metformin immediately fast glucose drop bother neuropathy month try lyrica month absolutely pain presently take gabapentin mg bedtime help slightly cost lyrica money window',
#  'genius psychiatrist start drug fall week feel bad start take fluoxetine month drug eventually take 400 mg day have manic thought amp episode psychiatrist decide bipolar start seroquel break nervous system readjust natural state end take month dose retrospect wish not take fluoxetineprozac seroquelquetiapine',
#  'take 25 mg help sleep day feel awful like d drug not wake last dayi will not take wife hand take night problem',
#  'year nexplanon problem get interested bleed month straight light fine year decide insert major problem s go downhill gain pound anxious mood begin change severe pain ovary get ultrasound sure not cyst normal continue severe pain finally decide remove everyte good far pain mood well ve lose weight',
#  'glad experience possible effect week notice mood get well thing happen life dog surgery breakup hair experiment go wrong able deal get bad feel spiral downward anxiety shoot way month number switch lexapro hope help',
#  'write expirence pill start actually work ve month let tell m go doctor switch sure baby effective eventually end have cramp go away start acne flare like nobodys buisness headache horrible daily ve suffer depression motivation burst cry reason angry character m disapointe hopefully find well option',
#  've implant month ve problem real bad acne breakout ve alway suffer acne get bad implant real bad breakout cheek chin think eat research find implant contain progesterone cause acne m plan remove implant look breakout implant',
#  'm amp birth control option begin patch go pill year md rxd loestrin year ago past year prove good far overall health few skin breakout light amp short period frequently donate blood irondefficient anemic well sex drive husband love moodiness bad gain 7 lb weight pinpoint directly pill choose healthy lifestyle past year negative pill stay day cycle breakthrough bleeding today md change loestrin reason',
#  'get insert year ago arm hurt day bruising literally forget remain time period pregnant weight gain convenient form birth control way body react get reinserte year get bruising bad',
#  'take medication year good stream prescribe doctor not empty bladder fully bladder muscle tone work great year age not bathroom fast urinate m go stop take difference reach bathroom let bladder',
#  'm smoker copd chronic bronchitis develop asthma ve take product yr illness weather decrease dramatically previously suffer pneumonia worsen bronchitis twice yr average year consistently take year round',
#  'cardura xl onoff year regularly recently want new prescription move europe doctor not product recommend alternative tamsulosin pradif t provide relieve urinate especially night block switch remain cardura xl find equivalent product europe call cardura cr perfect flow day night effect',
#  've drink 12yo relapse hard week ago manager work suspect drink work fire spend money leave bank try drink death free ride law school lose play big role depressive drinking get hospital begin go withdrawal sedate give librium prescription m pound male bf m strong healthy guy mg day taper second day decrease day pill m pill night exercise control cns excitement vivid dream save',
#  'take ocella month month experience weight loss clear skin find absolutely sex drive take ocella sex drive people',
#  'take week cause horrible headache borderline migraine start minute take pill away go sleep naseous dizzy constantly warm hot cause heart burn ve take pill zero interest sex',
#  'product work athletic preteen daughter begin involved sport lot sweat acne came duac acne clear control face not oily like couple blemish like',
#  'supplement levothyroxine night day difference long sleep time think clearly actually want thing',
#  'work great husband give cold medicine somewhat relieved extremely uncomfortable gas diarrhea think bad strain virus take medicine day min stomach problem quit night return vengeance dextromethorphan ingredient not reaction new red dye allergy m take ingredient',
#  'try sun relate acne medicine thing work aczone day face clear fast see skin look good year not irritate skin go light absorb right highly highly recommend',
#  'thyroid test show active dr increase levothyroxine mcg take hour stomach eat guestione pharmacist confirm hour wate difficult wait hour medication',
#  ...]

# %%
# Now we have three preprocessed lists on the refiew column bases on  3 strategies: only lemmitization, only lemmitization tokens and lem + stop words.
review_token_list_parallel_proc
review_token_list_parallel_proc_tokens
review_token_list_parallel_proc_stpwrd

# %% [markdown]
# Lets add the preprocessed lists to the dataframe:

# %%
# df_reviews['prep_review'] = review_token_list_parallel_proc
df_reviews['prep_review_token'] = review_token_list_parallel_proc_tokens
df_reviews['prep_review_stpwrd'] = review_token_list_parallel_proc_stpwrd

# %%
df_reviews
# Out:
#                         drugName                     condition  \
# 0                      Valsartan  Left Ventricular Dysfunction
# 1                     Guanfacine                          ADHD
# 2                         Lybrel                 Birth Control
# 3                     Ortho Evra                 Birth Control
# 4       Buprenorphine / naloxone             Opiate Dependence
# ...                          ...                           ...
# 161292                   Campral            Alcohol Dependence
# 161293            Metoclopramide               Nausea/Vomiting
# 161294                   Orencia          Rheumatoid Arthritis
# 161295        Thyroid desiccated           Underactive Thyroid
# 161296              Lubiprostone         Constipation, Chronic
#
#                                                    review  rating        date  \
# 0       "It has no side effect, I take it in combinati...       9  2012-05-20
# 1       "My son is halfway through his fourth week of ...       8  2010-04-27
# 2       "I used to take another oral contraceptive, wh...       5  2009-12-14
# 3       "This is my first time using any form of birth...       8  2015-11-03
# 4       "Suboxone has completely turned my life around...       9  2016-11-27
# ...                                                   ...     ...         ...
# 161292  "I wrote my first report in Mid-October of 201...      10  2015-05-31
# 161293  "I was given this in IV before surgey. I immed...       1  2011-11-01
# 161294  "Limited improvement after 4 months, developed...       2  2014-03-15
# 161295  "I&#039;ve been on thyroid medication 49 years...      10  2015-09-19
# 161296  "I&#039;ve had chronic constipation all my adu...       9  2014-12-13
#
#         usefulCount                                        prep_review  \
# 0                27  it have no side effect I take it in combinatio...
# 1               192  my son be halfway through his fourth week of i...
# 2                17  I use to take another oral contraceptive which...
# 3                10  this be my first time use any form of birth co...
# 4                37  suboxone have completely turn my life around I...
# ...             ...                                                ...
# 161292          125  I write my first report in midoctober of I hav...
# 161293           34  I be give this in iv before surgey I immediate...
# 161294           35  limit improvement after month develop bad rash...
# 161295           79  I ve be on thyroid medication year I spend my ...
# 161296          116  I ve have chronic constipation all my adult li...
#
#                                         prep_review_token  \
# 0       [it, have, no, side, effect, I, take, it, in, ...
# 1       [my, son, be, halfway, through, his, fourth, w...
# 2       [I, use, to, take, another, oral, contraceptiv...
# 3       [this, be, my, first, time, use, any, form, of...
# 4       [suboxone, have, completely, turn, my, life, a...
# ...                                                   ...
# 161292  [I, write, my, first, report, in, midoctober, ...
# 161293  [I, be, give, this, in, iv, before, surgey, I,...
# 161294  [limit, improvement, after, month, develop, ba...
# 161295  [I, ve, be, on, thyroid, medication, year, I, ...
# 161296  [I, ve, have, chronic, constipation, all, my, ...
#
#                                        prep_review_stpwrd
# 0                 effect combination bystolic mg fish oil
# 1       son halfway fourth week intuniv concerned begi...
# 2       oral contraceptive pill cycle happy light peri...
# 3       time form birth control m glad go patch month ...
# 4       suboxone completely turn life feel healthy m e...
# ...                                                   ...
# 161292  write report midoctober alcohol post reduce do...
# 161293  give iv surgey immediately anxious sit pa say ...
# 161294  limit improvement month develop bad rash md re...
# 161295  ve thyroid medication year spend synthroid t4 ...
# 161296  ve chronic constipation adult life try linzess...
#
# [161297 rows x 9 columns]

# %%
df_reviews.to_csv('Projects/preprocessed_reviews.csv', index=False)

# %%
df_test  = pd.read_csv('Projects/preprocessed_reviews.csv')
df_test.head(5)
# Out:
#                    drugName                     condition  \
# 0                 Valsartan  Left Ventricular Dysfunction
# 1                Guanfacine                          ADHD
# 2                    Lybrel                 Birth Control
# 3                Ortho Evra                 Birth Control
# 4  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating        date  \
# 0  "It has no side effect, I take it in combinati...       9  2012-05-20
# 1  "My son is halfway through his fourth week of ...       8  2010-04-27
# 2  "I used to take another oral contraceptive, wh...       5  2009-12-14
# 3  "This is my first time using any form of birth...       8  2015-11-03
# 4  "Suboxone has completely turned my life around...       9  2016-11-27
#
#    usefulCount                                        prep_review  \
# 0           27  it have no side effect I take it in combinatio...
# 1          192  my son be halfway through his fourth week of i...
# 2           17  I use to take another oral contraceptive which...
# 3           10  this be my first time use any form of birth co...
# 4           37  suboxone have completely turn my life around I...
#
#                                    prep_review_token  \
# 0  ['it', 'have', 'no', 'side', 'effect', 'I', 't...
# 1  ['my', 'son', 'be', 'halfway', 'through', 'his...
# 2  ['I', 'use', 'to', 'take', 'another', 'oral', ...
# 3  ['this', 'be', 'my', 'first', 'time', 'use', '...
# 4  ['suboxone', 'have', 'completely', 'turn', 'my...
#
#                                   prep_review_stpwrd
# 0            effect combination bystolic mg fish oil
# 1  son halfway fourth week intuniv concerned begi...
# 2  oral contraceptive pill cycle happy light peri...
# 3  time form birth control m glad go patch month ...
# 4  suboxone completely turn life feel healthy m e...

# %%
# In next notebook sentiment analysis.ipynb

# %% [markdown]
# ___
# ___
